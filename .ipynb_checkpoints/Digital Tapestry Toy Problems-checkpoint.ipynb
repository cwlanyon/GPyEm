# %%
import math
import torch
import gpytorch
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import emcee

import GPE_ensemble as GPE

import os
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
#from GPErks.gp.data.dataset import Dataset
from gpytorch.likelihoods import GaussianLikelihood
from gpytorch.means import LinearMean
from gpytorch.kernels import RBFKernel, ScaleKernel
from torchmetrics import MeanSquaredError, R2Score
#from GPErks.gp.experiment import GPExperiment
#from GPErks.train.emulator import GPEmulator
#from GPErks.perks.inference import Inference
#from GPErks.train.early_stop import NoEarlyStoppingCriterion
#from GPErks.train.early_stop import (
#    GLEarlyStoppingCriterion,
#    PQEarlyStoppingCriterion,
#    UPEarlyStoppingCriterion,
#)
#from GPErks.train.early_stop import PkEarlyStoppingCriterion



# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# set logger and enforce reproducibility
#from GPErks.log.logger import get_logger
#from GPErks.utils.random import set_seed
#log = get_logger()
seed = 7
#set_seed(seed)

# %%
def computeResponse(delta,length,width,time,u,k_0,R):
        """
        Computes concentrations.
        Arguments:
         source == forcing function (shape: Nt x Nx x Ny). Can either be generated by ... or determine manually.
         enforce_nonnegative = default False,. Setting to true will force concentration to be non-negative each iteration.
        returns array of concentrations (shape: Nt x Nx x Ny), given source. (also saved it in self.concentration)
        """
        #source = self.source
        
        #get the grid step sizes, their squares and the size of the grid
        
        dt = delta[0]
        dx = delta[1]
        dy = delta[2]
        dx2 = dx**2
        dy2 = dy**2
        Nt = int(time/dt)
        Nx = int(length/dx)
        Ny = int(width/dy)
        c=np.zeros((Nt,Nx,Ny))
        
        source = np.zeros((Nt,Nx,Ny))
        u=[u[0]*np.ones((Nt,Nx,Ny)),u[1]*np.ones((Nt,Nx,Ny))]
        source[0,int(Nx/10),int(Ny/10)]=1000
        
        c[0,:,:]=0
        for i in range(0,Nt-1):
            # Corner BCs 
            c[i+1,0,0]=c[i,0,0]+dt*( source[i,0,0] ) +dt*k_0*( 2*c[i,1,0]-2*c[i,0,0])/dx2 + dt*k_0*( 2*c[i,0,1]-2*c[i,0,0])/dy2 -dt*R*c[i,0,0]
            c[i+1,Nx-1,Ny-1]=c[i,Nx-1,Ny-1]+dt*( source[i,Nx-1,Ny-1])+dt*k_0*( 2*c[i,Nx-2,Ny-1]-2*c[i,Nx-1,Ny-1])/dx2 + dt*k_0*( 2*c[i,Nx-1,Ny-2]-2*c[i,Nx-1,Ny-1])/dy2-dt*R*c[i,Nx-1,Ny-1]
            c[i+1,0,Ny-1]=c[i,0,Ny-1]+dt*( source[i,0,Ny-1] ) +dt*k_0*( 2*c[i,1,Ny-1]-2*c[i,0,Ny-1])/dx2 + dt*k_0*( 2*c[i,0,Ny-2]-2*c[i,0,Ny-1])/dy2-dt*R*c[i,0,Ny-1]
            c[i+1,Nx-1,0]=c[i,Nx-1,0]+dt*( source[i,Nx-1,0])+dt*k_0*( 2*c[i,Nx-2,0]-2*c[i,Nx-1,0])/dx2 + dt*k_0*( 2*c[i,Nx-1,1]-2*c[i,Nx-1,0])/dy2-dt*R*c[i,Nx-1,0]
    
            c[i+1,1:Nx-1,0]=c[i,1:Nx-1,0]+dt*(source[i,1:Nx-1,0]-u[0][i,1:Nx-1,0]*(c[i,2:Nx,0]-c[i,0:Nx-2,0])/(2*dx)+k_0*(2*c[i,1:Nx-1,1]-2*c[i,1:Nx-1,0])/dy2 +k_0*(c[i,2:Nx,0]-2*c[i,1:Nx-1,0]+c[i,0:Nx-2,0] )/dx2 - R*c[i,1:Nx-1,0]     )
            c[i+1,1:Nx-1,Ny-1]=c[i,1:Nx-1,Ny-1]+dt*( source[i,1:Nx-1,Ny-1]-u[0][i,1:Nx-1,Ny-1]*(c[i,2:Nx,Ny-1]-c[i,0:Nx-2,Ny-1])/(2*dx)+k_0*(2*c[i,1:Nx-1,Ny-2]-2*c[i,1:Nx-1,Ny-1])/dy2 +k_0*(c[i,2:Nx,Ny-1]-2*c[i,1:Nx-1,Ny-1]+c[i,0:Nx-2,Ny-1] )/dx2 - R*c[i,1:Nx-1,Ny-1]     )  
            #for k in range(1,Ny-1):
                # x edge bcs
            c[i+1,Nx-1,1:Ny-1]=c[i,Nx-1,1:Ny-1]+dt*( source[i,Nx-1,1:Ny-1]-u[1][i,Nx-1,1:Ny-1]*(c[i,Nx-1,2:Ny]-c[i,Nx-1,0:Ny-2])/(2*dy)+k_0*(2*c[i,Nx-2,1:Ny-1]-2*c[i,Nx-1,1:Ny-1])/dx2 +k_0*(c[i,Nx-1,2:Ny]-2*c[i,Nx-1,1:Ny-1]+c[i,Nx-1,0:Ny-2] )/dy2  - R*c[i,Nx-1,1:Ny-1]   )
            c[i+1,0,1:Ny-1]=c[i,0,1:Ny-1]+dt*( source[i,0,1:Ny-1]-u[1][i,0,1:Ny-1]*(c[i,0,2:Ny]-c[i,0,0:Ny-2])/(2*dy)+k_0*(2*c[i,1,1:Ny-1]-2*c[i,0,1:Ny-1])/dx2 +k_0*(c[i,0,2:Ny]-2*c[i,0,1:Ny-1]+c[i,0,0:Ny-2] )/dy2 - R*c[i,0,1:Ny-1]    )     
                # Internal Calc
            c[i+1,1:Nx-1,1:Ny-1]=c[i,1:Nx-1,1:Ny-1] +dt*(source[i,1:Nx-1,1:Ny-1]-u[0][i,1:Nx-1,1:Ny-1]*(c[i,2:Nx,1:Ny-1]-c[i,0:Nx-2,1:Ny-1])/(2*dx) -u[1][i,1:Nx-1,1:Ny-1]*(c[i,1:Nx-1,2:Ny]-c[i,1:Nx-1,0:Ny-2] )/(2*dy) +k_0*(c[i,2:Nx,1:Ny-1]-2*c[i,1:Nx-1,1:Ny-1]  +c[i,0:Nx-2,1:Ny-1])/dx2+k_0*(c[i,1:Nx-1,2:Ny]-2*c[i,1:Nx-1,1:Ny-1]  +c[i,1:Nx-1,0:Ny-2])/dy2 - R*c[i,1:Nx-1,1:Ny-1])

        return c

# %%
def computeResponse(delta,length,width,time,u,k_0,R):
        """
        Computes concentrations.
        Arguments:
         source == forcing function (shape: Nt x Nx x Ny). Can either be generated by ... or determine manually.
         enforce_nonnegative = default False,. Setting to true will force concentration to be non-negative each iteration.
        returns array of concentrations (shape: Nt x Nx x Ny), given source. (also saved it in self.concentration)
        """
        #source = self.source
        
        #get the grid step sizes, their squares and the size of the grid
        
        dt = delta[0]
        dx = delta[1]
        dy = delta[2]
        dx2 = dx**2
        dy2 = dy**2
        Nt = int(time/dt)
        Nx = int(length/dx)
        Ny = int(width/dy)
        c=np.zeros((Nt,Nx,Ny))
        
        source = np.zeros((Nt,Nx,Ny))
        u=[u[0]*np.ones((Nt,Nx,Ny)),u[1]*np.ones((Nt,Nx,Ny))]
        source[0,int(Nx/100),int(Ny/100)]=1000
        
        c[0,:,:]=0
        for i in range(0,Nt-1):
            # Corner BCs 
            c[i+1,0,0]=0
            c[i+1,Nx-1,Ny-1]=0
            c[i+1,0,Ny-1]=0
            c[i+1,Nx-1,0]=0
    
            c[i+1,1:Nx-1,0]=0
            c[i+1,1:Nx-1,Ny-1]=0 
            #for k in range(1,Ny-1):
                # x edge bcs
            c[i+1,Nx-1,1:Ny-1]=0
            c[i+1,0,1:Ny-1]=0
                # Internal Calc
            c[i+1,1:Nx-1,1:Ny-1]=c[i,1:Nx-1,1:Ny-1] +dt*(source[i,1:Nx-1,1:Ny-1]-u[0][i,1:Nx-1,1:Ny-1]*(c[i,2:Nx,1:Ny-1]-c[i,0:Nx-2,1:Ny-1])/(2*dx) -u[1][i,1:Nx-1,1:Ny-1]*(c[i,1:Nx-1,2:Ny]-c[i,1:Nx-1,0:Ny-2] )/(2*dy) +k_0*(c[i,2:Nx,1:Ny-1]-2*c[i,1:Nx-1,1:Ny-1]  +c[i,0:Nx-2,1:Ny-1])/dx2+k_0*(c[i,1:Nx-1,2:Ny]-2*c[i,1:Nx-1,1:Ny-1]  +c[i,1:Nx-1,0:Ny-2])/dy2 - R*c[i,1:Nx-1,1:Ny-1])

        return c

# %%
adr=computeResponse([0.002,0.01,0.01],1,1,10,[0.1,0.1],0.001,0)

# %%
plt.imshow(adr[-1])
plt.colorbar()

# %%
np.sum(adr,axis=(1,2))
# Out:
# array([0.        , 2.        , 1.96      , ..., 0.13471968, 0.13434244,
#        0.13396595])

# %%
10/0.1
# Out:
# 100.0

# %%
plt.plot(np.sum(adr,axis=(1,2)))

# %%
def computeResponse(dt,time,theta):        
        """
        Computes the system response over time (returns a vector)
        Arguments:
        source == forcing function (shape: Nt). Can either be generated by ... or determine manually.
        returns array of concentrations (shape: Nt), given source. (also saved it in self.conc)
        """
  
        Nt = int(time/dt)
        dt2 = dt**2
        
        x=np.zeros((Nt))
        source=np.zeros((Nt))
        source[0]=1
        
        k_0,u,eta = theta

        x[0] = 0
        #x[1] = 0
        x[1] = ( 1.0/(-k_0+u*dt/2))*(k_0*(-2*x[0] + x[0] )+  (u*dt*x[0])/2.0- eta*x[0]*(dt2)+ source[0]*(dt2))
        for i in range(1, Nt-1):
            x[i+1] = ( 1.0/(-k_0+u*dt/2))*(k_0*(-2*x[i] + x[i-1] )+  (u*dt*x[i-1])/2.0- eta*x[i]*(dt2)+ source[i]*(dt2))
        

        return x

# %%
oscillator = computeResponse(0.01,10,[-0.5,0.1,0.5])

# %%
plt.plot(oscillator)

# %%
import scipy.stats.qmc as qmc

# %%
theta_sampler = qmc.LatinHypercube(d=3)
theta_sample = theta_sampler.random(n=180)

# %%
l_bounds = [-2,0,0]
u_bounds = [-0.1, 2,2]
theta = qmc.scale(theta_sample, l_bounds, u_bounds)

# %%
latent_sampler = qmc.LatinHypercube(d=1)
latent_sample = latent_sampler.random(n=18)

# %%
l_bounds = [5]
u_bounds = [10]
latent = qmc.scale(latent_sample, l_bounds, u_bounds)

# %%
y = np.zeros(180)
for i in range(180):
    y[i]=computeResponse(0.01,5,theta[i]).mean()

# %%
plt.plot(y)

# %%
# split original dataset in training, validation and testing sets
X=torch.tensor(theta)
y=torch.tensor(y)
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.1,
    random_state=seed
)

# %%
emulator=GPE.ensemble(X_train,y_train[:,None],mean_func='linear')
# Out:
# 0

# %%
emulator.R2(X_test,y_test[:,None])
# Out:
# /Users/pmzcwl/Documents/GitHub/Calibration/GPE_ensemble.py:206: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   R2_score=1-self.MSE(inputVals,outputVals)/torch.tensor(torch.var(outputVals,axis=0))
# tensor([0.5396], dtype=torch.float64, grad_fn=<RsubBackward1>)

# %%
latent
# Out:
# array([[7.54395297],
#        [7.80469155],
#        [8.55565538],
#        [6.98414382],
#        [5.29565031],
#        [9.55912388],
#        [9.27775319],
#        [7.46149959],
#        [6.60837808],
#        [8.95750195],
#        [8.12492937],
#        [8.62756125],
#        [9.91660759],
#        [5.8744873 ],
#        [6.32408193],
#        [5.64082251],
#        [5.1595784 ],
#        [6.69745761]])

# %%
inputs=[]
for i,l in enumerate(latent):
    theta_sampler = qmc.LatinHypercube(d=3)
    theta_sample = theta_sampler.random(n=180)
    l_bounds = [-2,0,0]
    u_bounds = [-0.1, 2,2]
    theta = qmc.scale(theta_sample, l_bounds, u_bounds)
    inputs.append(theta)

# %%
outputs = []
for i,l in enumerate(latent):
    outputs.append([])
    for j in range(180):
        #outputs[i].append(computeResponse(0.01,l,inputs[i][j]).mean())
        #outputs[i].append(computeResponse(0.01,l,inputs[i][j])[-1])
        response = computeResponse(0.01,l,inputs[i][j])
        outputs[i].append([response.max()-response.min(),response[-1],response.mean()])

# %%
R2_mean = np.zeros((3,len(inputs)) )
R2_std = np.zeros((3,len(inputs))) 
for i in range(len(inputs)):
    
    # split original dataset in training, validation and testing sets
    X=torch.tensor(inputs[i]).float()
    y=torch.tensor(outputs[i]).float()
    X_train, X_test, y_train, y_test = train_test_split(
        X,
        y,
        test_size=0.1,
        random_state=seed
    )
    emulator=GPE.ensemble(X_train,y_train,mean_func='linear')
    mean,std=emulator.R2_sample(X_test,y_test,100)
    R2_mean[:,i]=mean
    R2_std[:,i]=std
# Out:
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2

# %%
plt.plot(latent,R2_mean.T,'o')
plt.legend(['dif','end','mean'])

# %%
large_input = np.array(inputs[0:17]).reshape(17*180,3)

# %%
modeweights = np.repeat(latent[0:17],180)

# %%
large_input = np.concatenate((large_input,modeweights[:,None]),axis=1)

# %%
large_output = np.array(outputs[0:17]).reshape(17*180,3)

# %%
leftout_input = np.concatenate((inputs[17],np.repeat(latent[17],180)[:,None]),axis=1)

# %%
# split original dataset in training, validation and testing sets
X=torch.tensor(large_input)
y=torch.tensor(large_output)
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    train_size=720,
    random_state=seed
)

emulator=GPE.ensemble(X_train,y_train,mean_func='linear')

emulator.R2(X_test,y_test)
# Out:
# 0
# 1
# 2
# tensor([0.9613, 0.2676, 0.9697], dtype=torch.float64, grad_fn=<RsubBackward1>)

# %%
emulator.R2(torch.tensor(leftout_input),torch.tensor(outputs[17]))
# Out:
# tensor([ 0.9900, -0.4497,  0.6671], dtype=torch.float64,
#        grad_fn=<RsubBackward1>)

# %%
torch.cat(( (torch.tensor(inputs[0:1])+torch.tensor(inputs[1:18])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 torch.cat(( (torch.tensor(inputs[0:1])+torch.tensor(inputs[1:18]))))
#
# TypeError: cat(): argument 'tensors' (position 1) must be tuple of Tensors, not Tensor

# %%
large_input = np.array(inputs).reshape(18*180,3)

modeweights = np.repeat(latent,180)

large_input = np.concatenate((large_input,modeweights[:,None]),axis=1)

large_output = np.array(outputs).reshape(18*180,3)

# %%
torch.cat((torch.tensor(large_input[:,0:1]),torch.tensor(large_input[:,1:18])))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 torch.cat((torch.tensor(large_input[:,0:1]),torch.tensor(large_input[:,1:18])))
#
# RuntimeError: Sizes of tensors must match except in dimension 0. Expected size 1 but got size 3 for tensor number 1 in the list.

# %%
latent
# Out:
# array([[7.54395297],
#        [7.80469155],
#        [8.55565538],
#        [6.98414382],
#        [5.29565031],
#        [9.55912388],
#        [9.27775319],
#        [7.46149959],
#        [6.60837808],
#        [8.95750195],
#        [8.12492937],
#        [8.62756125],
#        [9.91660759],
#        [5.8744873 ],
#        [6.32408193],
#        [5.64082251],
#        [5.1595784 ],
#        [6.69745761]])

# %%
latent2=latent.copy()
np.delete(latent2,0)
# Out:
# array([7.80469155, 8.55565538, 6.98414382, 5.29565031, 9.55912388,
#        9.27775319, 7.46149959, 6.60837808, 8.95750195, 8.12492937,
#        8.62756125, 9.91660759, 5.8744873 , 6.32408193, 5.64082251,
#        5.1595784 , 6.69745761])

# %%
R2_in = torch.zeros((18,3))
R2_out = torch.zeros((18,3))

for i in range(18):
    
    
    
    large_input = np.array(inputs[0:i]+inputs[i+1:18]).reshape(17*180,3)

    latent2=latent.copy()
    latent2=np.delete(latent2,i)

    modeweights = np.repeat(latent2,180)

    large_input = np.concatenate((large_input,modeweights[:,None]),axis=1)

    large_output = np.array(outputs[0:i]+outputs[i:18]).reshape(17*180,3)
    
    leftout_input=torch.tensor(np.concatenate((inputs[i],np.repeat(latent[i],180)[:,None]),axis=1))
    leftout_output=torch.tensor(outputs[i])
    
    # split original dataset in training, validation and testing sets
    X=torch.tensor(large_input)
    y=torch.tensor(large_output)
    X_train, X_test, y_train, y_test = train_test_split(
        X,
        y,
        train_size=720,
        random_state=seed
    )

    emulator=GPE.ensemble(X_train,y_train,mean_func='linear')

    R2_in[i]=emulator.R2(X_test,y_test)

    R2_out[i]=emulator.R2(leftout_input,leftout_output)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 17
#      13 modeweights = np.repeat(latent2,180)
#      15 large_input = np.concatenate((large_input,modeweights[:,None]),axis=1)
# ---> 17 large_output = np.array(outputs[0:i]+outputs[i:18]).reshape(17*180,3)
#      19 leftout_input=torch.tensor(np.concatenate((inputs[i],np.repeat(latent[i],180)[:,None]),axis=1))
#      20 leftout_output=torch.tensor(outputs[i])
#
# ValueError: cannot reshape array of size 9720 into shape (3060,3)

# %%
latent2
# Out:
# array([[7.54395297],
#        [7.80469155],
#        [8.55565538],
#        [6.98414382],
#        [5.29565031],
#        [9.55912388],
#        [9.27775319],
#        [7.46149959],
#        [6.60837808],
#        [8.95750195],
#        [8.12492937],
#        [8.62756125],
#        [9.91660759],
#        [5.8744873 ],
#        [6.32408193],
#        [5.64082251],
#        [5.1595784 ],
#        [6.69745761]])
