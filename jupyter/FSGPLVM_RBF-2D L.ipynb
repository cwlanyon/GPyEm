# %%
import math
import torch
import gpytorch
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt 

from GPyEm import GPE_ensemble as GPE
from FSGPLVM import FSGPLVM as LVM

# %%
import sklearn.metrics as sk

# %% [markdown]
# ### Fully supervised GPLVM (we should come up with a better acronym/name)
#
# Observations:
# $$Y = [y_1,...,y_N], \ y_n \in R^{p}$$
# Model parameters
# $$X = [x_1,...,x_N], \ x_n \in R^{p\times q}$$
# Latent parameters/features
# $$L = [l_1,...,l_N], \ l_n \in R^{d }$$
# With $d<q$ and $L\sim N(0,I)$.
#
# We want to find a function $f_\theta$ such that:
# $$ Y = f_\theta(X,L)+\epsilon $$
# Let's make $f$ a GP, as we like to, with mean $m_\theta(X,L)$ and covariance $K_\theta((X,L),(X',L'))$
# We would like to learn $L$ and $\theta$ (the hyper-parameters).
#
# As a cost function we use the likelihood
# $$p(Y,L|X) = p(Y|L,X)p(L) $$
# and as $f$ is a GP,
# $$p(Y|L,X) \sim N(m_\theta(X,L), K_\theta((X,L),(X,L)))$$
#
# Taking the log we have
# $$\log p(Y,L|X) = \log p(Y|L,X)+\log p(L) $$
# $$ = -\frac{NP}{2}\log(2\pi)-\frac{1}{2}\log|K_\theta|-\frac{1}{2}(Y-m_\theta(X,L))^\top\ K_\theta^{-1}(Y-m_\theta(X,L))-\frac{N*LDIM}{2}\log(2\pi)-\frac{1}{2}\log|I|-\frac{1}{2}(L)^\top I^{-1}(L)) $$

# %% [markdown]
# to calculate $\log |K|$ we use the fact that $\log |K| = 2\Sigma (\log\mathrm{diag}(L)_i)$, where $L$ is the cholesky decomposition of $K$.

# %%
def multivariate_ll(y,mu,K,K_inv=None):
    det = 2*torch.sum(torch.log(torch.diag(torch.linalg.cholesky(K))))
    if K_inv==None:
        ll = -((y.shape[0]*y.shape[1])/2)*torch.log(2*torch.tensor(torch.pi))-0.5*y.shape[1]*det-0.5*torch.sum(torch.diag(torch.matmul((y-mu).T,torch.linalg.solve(K,y-mu))))
        #ll = -(y.shape[0]/2)*torch.log(2*torch.tensor(torch.pi))-0.5*det-0.5*torch.matmul((y-mu).T,torch.linalg.solve(K,y-mu))
        
    return ll

# %%
import numpy as np
from sklearn.metrics.pairwise import rbf_kernel



def rbf(X1,L1,X2,L2,scaling,lengthscale,p1,p2):
    X1=X1/torch.sqrt(lengthscale)
    X2=X2/torch.sqrt(lengthscale)
    X_1 = (torch.cat((X1,torch.repeat_interleave(L1,p1,dim=0)),axis=1)).detach().numpy()
    X_2 = (torch.cat((X2,torch.repeat_interleave(L2,p2,dim=0)),axis=1)).detach().numpy()
    rbf = scaling * torch.tensor(rbf_kernel(X_1,X_2, gamma = 1))

    return rbf

def rbf(X1,L1,X2,L2,scaling,lengthscale,p1,p2):
    X_1 = (torch.cat((X1,torch.repeat_interleave(L1,p1,dim=0)),axis=1)/torch.sqrt(lengthscale)).detach().numpy()
    X_2 = (torch.cat((X2,torch.repeat_interleave(L2,p2,dim=0)),axis=1)/torch.sqrt(lengthscale)).detach().numpy()
    rbf = scaling * torch.tensor(rbf_kernel(X_1,X_2, gamma = 1))

    return rbf

def rbf2(X1,X2,scaling,lengthscale):

    X_1 = (X1/torch.sqrt(lengthscale)).detach().numpy()
    X_2 = (X2/torch.sqrt(lengthscale)).detach().numpy()
    rbf = scaling * torch.tensor(rbf_kernel(X_1,X_2, gamma = 1))

    return rbf


def rbf(X1,X2,scaling,lengthscale):

    X_1 = X1/lengthscale
    X_2 = X2/lengthscale
    rbf = scaling * torch.exp(-0.5*torch.cdist(X_1,X_2,p=2)**2)

    return rbf

# %% [markdown]
# For the linear kernel we don't really have any separation possibilities that are useful to us from an inverting persepctive, as far as I can tell?
# $$K_{ij}=x_i^\top x_j + l_i^\top l_j$$
#
# So we don't get much in the way of help here.

# %%
def linear(X1,L1,X2,L2,X_length,L_length,p1,p2):
    
    L1=L1/torch.sqrt(L_scale)
    X1=X1/torch.sqrt(X_scale)
    X_1 = torch.cat((X1,torch.repeat_interleave(L1,p1)[:,None]),axis=1)

    L2=L2/torch.sqrt(L_scale)
    X2=X2/torch.sqrt(X_scale)
    X_2 = torch.cat((X2,torch.repeat_interleave(L2,p2)[:,None]),axis=1)
    
    rbf =  torch.matmul(X_1, X_2.T) 
    return rbf

# %% [markdown]
# sample $L$ and $X$ from $U[-1,1]$
#
# Here we do $x_i \neq x_j$, just for the sake of it

# %% [markdown]
# Posterior mean: $$m(X^*,X)+K((X^*,L^*),(X,L))(K((X,L),(X,L))+\sigma^2I)^{-1}(Y-m(X,X))$$
#
# Posterior covar: $$K((X^*,L^*),(X^*,L^*))+\sigma^2 - K((X^*,L^*),(X,L))(K((X,L),(X,L))+\sigma^2I]^{-1}K((X^*,L^*),(X,L))^\top$$

# %%
def posterior_theta(Y,X_test,L_test,p_test,X_train,L_train,p_train,scaling,lengthscale,sigma2,mean):
    K = rbf(X_train,L_train,X_train,L_train,scaling,lengthscale,p_train,p_train)+sigma2*torch.eye(X_train.shape[0])
    K_s = rbf(X_test,L_test,X_train,L_train,scaling,lengthscale,p_test,p_train)
    K_ss = rbf(X_test,L_test,X_test,L_test,scaling,lengthscale,p_test,p_test)

    mean_p = mean+torch.matmul(K_s,torch.linalg.solve(K,Y-mean))
    K_p = K_ss-torch.matmul(K_s,torch.linalg.solve(K,K_s.T))+sigma2
    return mean_p, K_p

# %%
def posterior_theta(Y,X_test,X_train,scaling,lengthscale,sigma2,mean):
    K = rbf(X_train,X_train,scaling,lengthscale)+sigma2*torch.eye(X_train.shape[0])
    K_s = rbf(X_test,X_train,scaling,lengthscale)
    K_ss = rbf(X_test,X_test,scaling,lengthscale)

    mean_p = mean+torch.matmul(K_s,torch.linalg.solve(K,Y-mean))
    K_p = K_ss-torch.matmul(K_s,torch.linalg.solve(K,K_s.T))+sigma2
    return mean_p, K_p

# %% [markdown]
# ### Test 1

# %%
N = 10 #number of systems
p = 20 #observations per system
alpha=10
beta=-7
zeta=1

# %%
L_true=torch.FloatTensor(N, 2).uniform_(1, 4)
L_true =torch.normal(0,torch.ones(L_true.shape[0],L_true.shape[1]))

# %%
L_true
# Out:
# tensor([[ 0.0326,  0.0399],
#         [ 0.1502, -0.2088],
#         [-0.3981,  0.9371],
#         [-0.2373,  0.2019],
#         [-0.2051,  0.0582],
#         [-0.3962,  1.6413],
#         [-0.3234,  0.0565],
#         [-0.8744, -0.9987],
#         [ 0.9698, -0.0134],
#         [-1.4175,  0.3266]])

# %%
multivariate_ll(L_true,0,torch.eye(N),K_inv=None)
# Out:
# tensor(-22.8914)

# %%
import scipy
np.sum(scipy.stats.multivariate_normal.logpdf(L_true.T.detach().numpy(),cov=np.eye(N)))
# Out:
# -22.89139770281755

# %%
X_train=torch.torch.FloatTensor(N*p, 1).uniform_(-2, 2)
X_test=torch.torch.FloatTensor(N*p, 1).uniform_(-2, 2)

# %%
L_true[[0]][0]
# Out:
# tensor([0.0326, 0.0399])

# %%
def true_func(X,L,alpha,beta,zeta):
    tf = alpha*X*X*L[0]+L[1]*beta+torch.normal(0,0.0001*torch.ones(X.shape[0],1))
    tf2 = alpha*X*X*L[1]**2-L[0]*beta+torch.normal(0,0.0001*torch.ones(X.shape[0],1))
    return torch.cat([tf,tf2],axis=1)

# %%
y=[]
y_test = []
for i in range(N):
    y.append(true_func(X_train[i*p:(i+1)*p],L_true[i,:],alpha,beta,zeta))
    y_test.append(true_func(X_test[i*p:(i+1)*p],L_true[i,:],alpha,beta,zeta))

# %%
Y=torch.cat(y,axis=0)
Y_test=torch.cat(y_test)

# %%
Y.shape
# Out:
# torch.Size([200, 2])

# %%
for i in range(N):
    plt.plot(X_train[i*p:(i+1)*p,0].detach().numpy(),Y[i*p:(i+1)*p].detach().numpy(),'o')

# %%
Y_mean = Y.mean()
Y_std = Y.std()

X_mean = X_train.mean()
X_std =X_train.std()

#X_train = (X_train-X_mean)/X_std
#X_test = (X_test-X_mean)/X_std

#Y=(Y-Y_mean)/Y_std
#Y_test=(Y_test-Y_mean)/Y_std

# %%
X_all_train = (torch.cat((X_train,torch.repeat_interleave(L_true,p,dim=0)),axis=1))
X_all_test = (torch.cat((X_test,torch.repeat_interleave(L_true,p,dim=0)),axis=1))

# %%
emulator=GPE.ensemble(X_all_train,Y,mean_func='zero',training_iter=1000)
# Out:
# 0
# /Users/pmzcwl/anaconda3/lib/python3.11/site-packages/linear_operator/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-06 to the diagonal
#   warnings.warn(
# /Users/pmzcwl/anaconda3/lib/python3.11/site-packages/linear_operator/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-05 to the diagonal
#   warnings.warn(
# 1

# %%
emulator.R2(X_all_test,Y_test)
# Out:
# tensor([0.9999, 1.0000], grad_fn=<RsubBackward1>)

# %%
L =torch.normal(0,torch.ones(L_true.shape[0],L_true.shape[1])).clone().detach().requires_grad_(True)
XL_train = torch.cat((X_train,torch.repeat_interleave(L,p,dim=0)),axis=1)

# %%
LVemulator = LVM.LVE(XL_train,Y,0.01,p,N,1,training_iter=1000,lr=1e-4)
# Out:
# tensor(8373.9883, grad_fn=<NegBackward0>)

# %%
LVemulator.optimise(1000000,lr=1e-5)
# Out:
# tensor(4691.3047, grad_fn=<NegBackward0>)
# tensor(3588.0161, grad_fn=<NegBackward0>)
# tensor(3796.6328, grad_fn=<NegBackward0>)
# tensor(3282.2031, grad_fn=<NegBackward0>)
# tensor(2918.9358, grad_fn=<NegBackward0>)
# tensor(2660.5596, grad_fn=<NegBackward0>)
# tensor(2471.3145, grad_fn=<NegBackward0>)
# tensor(2328.4199, grad_fn=<NegBackward0>)
# tensor(2221.0098, grad_fn=<NegBackward0>)
# tensor(2143.7673, grad_fn=<NegBackward0>)
# tensor(2088.4131, grad_fn=<NegBackward0>)
# tensor(2046.5365, grad_fn=<NegBackward0>)
# tensor(2012.7413, grad_fn=<NegBackward0>)
# tensor(1983.7205, grad_fn=<NegBackward0>)
# tensor(1957.7002, grad_fn=<NegBackward0>)
# tensor(1934.1509, grad_fn=<NegBackward0>)
# tensor(1912.9814, grad_fn=<NegBackward0>)
# tensor(1894.0653, grad_fn=<NegBackward0>)
# tensor(1876.8140, grad_fn=<NegBackward0>)
# tensor(1858.5251, grad_fn=<NegBackward0>)
# tensor(1838.6204, grad_fn=<NegBackward0>)
# tensor(1819.9758, grad_fn=<NegBackward0>)
# tensor(1802.0068, grad_fn=<NegBackward0>)
# tensor(1786.9205, grad_fn=<NegBackward0>)
# tensor(1775.4531, grad_fn=<NegBackward0>)
# tensor(1766.9786, grad_fn=<NegBackward0>)
# tensor(1760.2361, grad_fn=<NegBackward0>)
# tensor(1754.3700, grad_fn=<NegBackward0>)
# tensor(1748.8063, grad_fn=<NegBackward0>)
# tensor(1743.3300, grad_fn=<NegBackward0>)
# tensor(1737.7009, grad_fn=<NegBackward0>)
# tensor(1732.5565, grad_fn=<NegBackward0>)
# tensor(1728.2538, grad_fn=<NegBackward0>)
# tensor(1723.8778, grad_fn=<NegBackward0>)
# tensor(1714.9695, grad_fn=<NegBackward0>)
# tensor(1699.6270, grad_fn=<NegBackward0>)
# tensor(1684.1473, grad_fn=<NegBackward0>)
# tensor(1666.1353, grad_fn=<NegBackward0>)
# tensor(1643.3751, grad_fn=<NegBackward0>)
# tensor(1617.9629, grad_fn=<NegBackward0>)
# tensor(1593.6992, grad_fn=<NegBackward0>)
# tensor(1573.0328, grad_fn=<NegBackward0>)
# tensor(1555.3586, grad_fn=<NegBackward0>)
# tensor(1535.4116, grad_fn=<NegBackward0>)
# tensor(1517.7269, grad_fn=<NegBackward0>)
# tensor(1509.2129, grad_fn=<NegBackward0>)
# tensor(1503.7046, grad_fn=<NegBackward0>)
# tensor(1499.2542, grad_fn=<NegBackward0>)
# tensor(1495.7565, grad_fn=<NegBackward0>)
# tensor(1493.0574, grad_fn=<NegBackward0>)
# tensor(1490.9164, grad_fn=<NegBackward0>)
# tensor(1489.1406, grad_fn=<NegBackward0>)
# tensor(1487.5480, grad_fn=<NegBackward0>)
# tensor(1485.4584, grad_fn=<NegBackward0>)
# tensor(1472.9061, grad_fn=<NegBackward0>)
# tensor(1456.7983, grad_fn=<NegBackward0>)
# tensor(1449.3574, grad_fn=<NegBackward0>)
# tensor(1442.9578, grad_fn=<NegBackward0>)
# tensor(1437.3357, grad_fn=<NegBackward0>)
# tensor(1432.7407, grad_fn=<NegBackward0>)
# tensor(1429.3430, grad_fn=<NegBackward0>)
# tensor(1427.1345, grad_fn=<NegBackward0>)
# tensor(1425.8591, grad_fn=<NegBackward0>)
# tensor(1425.1044, grad_fn=<NegBackward0>)
# tensor(1424.5225, grad_fn=<NegBackward0>)
# tensor(1423.9823, grad_fn=<NegBackward0>)
# tensor(1423.4530, grad_fn=<NegBackward0>)
# tensor(1422.9393, grad_fn=<NegBackward0>)
# tensor(1422.4375, grad_fn=<NegBackward0>)
# tensor(1421.9448, grad_fn=<NegBackward0>)
# tensor(1421.4644, grad_fn=<NegBackward0>)
# tensor(1420.9941, grad_fn=<NegBackward0>)
# tensor(1420.5320, grad_fn=<NegBackward0>)
# tensor(1420.0831, grad_fn=<NegBackward0>)
# tensor(1419.6416, grad_fn=<NegBackward0>)
# tensor(1419.2104, grad_fn=<NegBackward0>)
# tensor(1418.7860, grad_fn=<NegBackward0>)
# tensor(1418.3723, grad_fn=<NegBackward0>)
# tensor(1417.9604, grad_fn=<NegBackward0>)
# tensor(1417.5604, grad_fn=<NegBackward0>)
# tensor(1417.1654, grad_fn=<NegBackward0>)
# tensor(1416.7819, grad_fn=<NegBackward0>)
# tensor(1416.3979, grad_fn=<NegBackward0>)
# tensor(1416.0294, grad_fn=<NegBackward0>)
# tensor(1415.6689, grad_fn=<NegBackward0>)
# tensor(1415.3064, grad_fn=<NegBackward0>)
# tensor(1414.9558, grad_fn=<NegBackward0>)
# tensor(1414.6096, grad_fn=<NegBackward0>)
# tensor(1414.2681, grad_fn=<NegBackward0>)
# tensor(1413.9355, grad_fn=<NegBackward0>)
# tensor(1413.6056, grad_fn=<NegBackward0>)
# tensor(1413.2832, grad_fn=<NegBackward0>)
# tensor(1412.9622, grad_fn=<NegBackward0>)
# tensor(1412.6489, grad_fn=<NegBackward0>)
# tensor(1412.3438, grad_fn=<NegBackward0>)
# tensor(1412.0416, grad_fn=<NegBackward0>)
# tensor(1411.7448, grad_fn=<NegBackward0>)
# tensor(1411.4504, grad_fn=<NegBackward0>)
# tensor(1411.1614, grad_fn=<NegBackward0>)
# tensor(1410.8774, grad_fn=<NegBackward0>)
# tensor(1410.6017, grad_fn=<NegBackward0>)
# tensor(1410.3217, grad_fn=<NegBackward0>)
# tensor(1410.0515, grad_fn=<NegBackward0>)
# tensor(1409.7856, grad_fn=<NegBackward0>)
# tensor(1409.5208, grad_fn=<NegBackward0>)
# tensor(1409.2615, grad_fn=<NegBackward0>)
# tensor(1409.0061, grad_fn=<NegBackward0>)
# tensor(1408.7502, grad_fn=<NegBackward0>)
# tensor(1408.5034, grad_fn=<NegBackward0>)
# tensor(1408.2617, grad_fn=<NegBackward0>)
# tensor(1408.0173, grad_fn=<NegBackward0>)
# tensor(1407.7815, grad_fn=<NegBackward0>)
# tensor(1407.5449, grad_fn=<NegBackward0>)
# tensor(1407.3119, grad_fn=<NegBackward0>)
# tensor(1407.0833, grad_fn=<NegBackward0>)
# tensor(1406.8563, grad_fn=<NegBackward0>)
# tensor(1406.6296, grad_fn=<NegBackward0>)
# tensor(1406.4158, grad_fn=<NegBackward0>)
# tensor(1406.1943, grad_fn=<NegBackward0>)
# tensor(1405.9774, grad_fn=<NegBackward0>)
# tensor(1405.7673, grad_fn=<NegBackward0>)
# tensor(1405.5566, grad_fn=<NegBackward0>)
# tensor(1405.3478, grad_fn=<NegBackward0>)
# tensor(1405.1418, grad_fn=<NegBackward0>)
# tensor(1404.9365, grad_fn=<NegBackward0>)
# tensor(1404.7358, grad_fn=<NegBackward0>)
# tensor(1404.5403, grad_fn=<NegBackward0>)
# tensor(1404.3427, grad_fn=<NegBackward0>)
# tensor(1404.1449, grad_fn=<NegBackward0>)
# tensor(1403.9573, grad_fn=<NegBackward0>)
# tensor(1403.7671, grad_fn=<NegBackward0>)
# tensor(1403.5833, grad_fn=<NegBackward0>)
# tensor(1403.3986, grad_fn=<NegBackward0>)
# tensor(1403.2131, grad_fn=<NegBackward0>)
# tensor(1403.0317, grad_fn=<NegBackward0>)
# tensor(1402.8489, grad_fn=<NegBackward0>)
# tensor(1402.6782, grad_fn=<NegBackward0>)
# tensor(1402.5073, grad_fn=<NegBackward0>)
# tensor(1402.3286, grad_fn=<NegBackward0>)
# tensor(1402.1644, grad_fn=<NegBackward0>)
# tensor(1401.9915, grad_fn=<NegBackward0>)
# tensor(1401.8252, grad_fn=<NegBackward0>)
# tensor(1401.6626, grad_fn=<NegBackward0>)
# tensor(1401.4934, grad_fn=<NegBackward0>)
# tensor(1401.3376, grad_fn=<NegBackward0>)
# tensor(1401.1744, grad_fn=<NegBackward0>)
# tensor(1401.0122, grad_fn=<NegBackward0>)
# tensor(1400.8595, grad_fn=<NegBackward0>)
# tensor(1400.7050, grad_fn=<NegBackward0>)
# tensor(1400.5532, grad_fn=<NegBackward0>)
# tensor(1400.4012, grad_fn=<NegBackward0>)
# tensor(1400.2477, grad_fn=<NegBackward0>)
# tensor(1400.0969, grad_fn=<NegBackward0>)
# tensor(1399.9502, grad_fn=<NegBackward0>)
# tensor(1399.8090, grad_fn=<NegBackward0>)
# tensor(1399.6619, grad_fn=<NegBackward0>)
# tensor(1399.5233, grad_fn=<NegBackward0>)
# tensor(1399.3792, grad_fn=<NegBackward0>)
# tensor(1399.2402, grad_fn=<NegBackward0>)
# tensor(1399.0986, grad_fn=<NegBackward0>)
# tensor(1398.9662, grad_fn=<NegBackward0>)
# tensor(1398.8264, grad_fn=<NegBackward0>)
# tensor(1398.6907, grad_fn=<NegBackward0>)
# tensor(1398.5586, grad_fn=<NegBackward0>)
# tensor(1398.4309, grad_fn=<NegBackward0>)
# tensor(1398.2960, grad_fn=<NegBackward0>)
# tensor(1398.1675, grad_fn=<NegBackward0>)
# tensor(1398.0410, grad_fn=<NegBackward0>)
# tensor(1397.9099, grad_fn=<NegBackward0>)
# tensor(1397.7904, grad_fn=<NegBackward0>)
# tensor(1397.6606, grad_fn=<NegBackward0>)
# tensor(1397.5342, grad_fn=<NegBackward0>)
# tensor(1397.4158, grad_fn=<NegBackward0>)
# tensor(1397.2947, grad_fn=<NegBackward0>)
# tensor(1397.1787, grad_fn=<NegBackward0>)
# tensor(1397.0530, grad_fn=<NegBackward0>)
# tensor(1396.9315, grad_fn=<NegBackward0>)
# tensor(1396.8127, grad_fn=<NegBackward0>)
# tensor(1396.7012, grad_fn=<NegBackward0>)
# tensor(1396.5841, grad_fn=<NegBackward0>)
# tensor(1396.4646, grad_fn=<NegBackward0>)
# tensor(1396.3562, grad_fn=<NegBackward0>)
# tensor(1396.2418, grad_fn=<NegBackward0>)
# tensor(1396.1263, grad_fn=<NegBackward0>)
# tensor(1396.0201, grad_fn=<NegBackward0>)
# tensor(1395.9075, grad_fn=<NegBackward0>)
# tensor(1395.8022, grad_fn=<NegBackward0>)
# tensor(1395.6882, grad_fn=<NegBackward0>)
# tensor(1395.5867, grad_fn=<NegBackward0>)
# tensor(1395.4777, grad_fn=<NegBackward0>)
# tensor(1395.3694, grad_fn=<NegBackward0>)
# tensor(1395.2721, grad_fn=<NegBackward0>)
# tensor(1395.1678, grad_fn=<NegBackward0>)
# tensor(1395.0583, grad_fn=<NegBackward0>)
# tensor(1394.9576, grad_fn=<NegBackward0>)
# tensor(1394.8563, grad_fn=<NegBackward0>)
# tensor(1394.7546, grad_fn=<NegBackward0>)
# tensor(1394.6531, grad_fn=<NegBackward0>)
# tensor(1394.5542, grad_fn=<NegBackward0>)
# tensor(1394.4552, grad_fn=<NegBackward0>)
# tensor(1394.3549, grad_fn=<NegBackward0>)
# tensor(1394.2542, grad_fn=<NegBackward0>)
# tensor(1394.1692, grad_fn=<NegBackward0>)
# tensor(1394.0752, grad_fn=<NegBackward0>)
# tensor(1393.9714, grad_fn=<NegBackward0>)
# tensor(1393.8779, grad_fn=<NegBackward0>)
# tensor(1393.7855, grad_fn=<NegBackward0>)
# tensor(1393.6945, grad_fn=<NegBackward0>)
# tensor(1393.5981, grad_fn=<NegBackward0>)
# tensor(1393.5101, grad_fn=<NegBackward0>)
# tensor(1393.4133, grad_fn=<NegBackward0>)
# tensor(1393.3284, grad_fn=<NegBackward0>)
# tensor(1393.2405, grad_fn=<NegBackward0>)
# tensor(1393.1520, grad_fn=<NegBackward0>)
# tensor(1393.0562, grad_fn=<NegBackward0>)
# tensor(1392.9780, grad_fn=<NegBackward0>)
# tensor(1392.8889, grad_fn=<NegBackward0>)
# tensor(1392.8071, grad_fn=<NegBackward0>)
# tensor(1392.7192, grad_fn=<NegBackward0>)
# tensor(1392.6292, grad_fn=<NegBackward0>)
# tensor(1392.5483, grad_fn=<NegBackward0>)
# tensor(1392.4620, grad_fn=<NegBackward0>)
# tensor(1392.3811, grad_fn=<NegBackward0>)
# tensor(1392.2972, grad_fn=<NegBackward0>)
# tensor(1392.2114, grad_fn=<NegBackward0>)
# tensor(1392.1321, grad_fn=<NegBackward0>)
# tensor(1392.0500, grad_fn=<NegBackward0>)
# tensor(1391.9690, grad_fn=<NegBackward0>)
# tensor(1391.8789, grad_fn=<NegBackward0>)
# tensor(1391.8086, grad_fn=<NegBackward0>)
# tensor(1391.7327, grad_fn=<NegBackward0>)
# tensor(1391.6580, grad_fn=<NegBackward0>)
# tensor(1391.5740, grad_fn=<NegBackward0>)
# tensor(1391.4983, grad_fn=<NegBackward0>)
# tensor(1391.4207, grad_fn=<NegBackward0>)
# tensor(1391.3413, grad_fn=<NegBackward0>)
# tensor(1391.2694, grad_fn=<NegBackward0>)
# tensor(1391.1885, grad_fn=<NegBackward0>)
# tensor(1391.1102, grad_fn=<NegBackward0>)
# tensor(1391.0457, grad_fn=<NegBackward0>)
# tensor(1390.9720, grad_fn=<NegBackward0>)
# tensor(1390.8953, grad_fn=<NegBackward0>)
# tensor(1390.8285, grad_fn=<NegBackward0>)
# tensor(1390.7465, grad_fn=<NegBackward0>)
# tensor(1390.6765, grad_fn=<NegBackward0>)
# tensor(1390.6042, grad_fn=<NegBackward0>)
# tensor(1390.5316, grad_fn=<NegBackward0>)
# tensor(1390.4651, grad_fn=<NegBackward0>)
# tensor(1390.3876, grad_fn=<NegBackward0>)
# tensor(1390.3190, grad_fn=<NegBackward0>)
# tensor(1390.2441, grad_fn=<NegBackward0>)
# tensor(1390.1809, grad_fn=<NegBackward0>)
# tensor(1390.1183, grad_fn=<NegBackward0>)
# tensor(1390.0476, grad_fn=<NegBackward0>)
# tensor(1389.9780, grad_fn=<NegBackward0>)
# tensor(1389.9102, grad_fn=<NegBackward0>)
# tensor(1389.8423, grad_fn=<NegBackward0>)
# tensor(1389.7693, grad_fn=<NegBackward0>)
# tensor(1389.7117, grad_fn=<NegBackward0>)
# tensor(1389.6458, grad_fn=<NegBackward0>)
# tensor(1389.5825, grad_fn=<NegBackward0>)
# tensor(1389.5093, grad_fn=<NegBackward0>)
# tensor(1389.4443, grad_fn=<NegBackward0>)
# tensor(1389.3811, grad_fn=<NegBackward0>)
# tensor(1389.3185, grad_fn=<NegBackward0>)
# tensor(1389.2548, grad_fn=<NegBackward0>)
# tensor(1389.1941, grad_fn=<NegBackward0>)
# tensor(1389.1273, grad_fn=<NegBackward0>)
# tensor(1389.0698, grad_fn=<NegBackward0>)
# tensor(1389.0046, grad_fn=<NegBackward0>)
# tensor(1388.9373, grad_fn=<NegBackward0>)
# tensor(1388.8804, grad_fn=<NegBackward0>)
# tensor(1388.8171, grad_fn=<NegBackward0>)
# tensor(1388.7605, grad_fn=<NegBackward0>)
# tensor(1388.6913, grad_fn=<NegBackward0>)
# tensor(1388.6377, grad_fn=<NegBackward0>)
# tensor(1388.5814, grad_fn=<NegBackward0>)
# tensor(1388.5160, grad_fn=<NegBackward0>)
# tensor(1388.4624, grad_fn=<NegBackward0>)
# tensor(1388.3993, grad_fn=<NegBackward0>)
# tensor(1388.3420, grad_fn=<NegBackward0>)
# tensor(1388.2802, grad_fn=<NegBackward0>)
# tensor(1388.2253, grad_fn=<NegBackward0>)
# tensor(1388.1653, grad_fn=<NegBackward0>)
# tensor(1388.1107, grad_fn=<NegBackward0>)
# tensor(1388.0642, grad_fn=<NegBackward0>)
# tensor(1388.0032, grad_fn=<NegBackward0>)
# tensor(1387.9485, grad_fn=<NegBackward0>)
# tensor(1387.8810, grad_fn=<NegBackward0>)
# tensor(1387.8280, grad_fn=<NegBackward0>)
# tensor(1387.7653, grad_fn=<NegBackward0>)
# tensor(1387.7175, grad_fn=<NegBackward0>)
# tensor(1387.6608, grad_fn=<NegBackward0>)
# tensor(1387.6058, grad_fn=<NegBackward0>)
# tensor(1387.5527, grad_fn=<NegBackward0>)
# tensor(1387.4980, grad_fn=<NegBackward0>)
# tensor(1387.4475, grad_fn=<NegBackward0>)
# tensor(1387.3883, grad_fn=<NegBackward0>)
# tensor(1387.3311, grad_fn=<NegBackward0>)
# tensor(1387.2822, grad_fn=<NegBackward0>)
# tensor(1387.2340, grad_fn=<NegBackward0>)
# tensor(1387.1837, grad_fn=<NegBackward0>)
# tensor(1387.1298, grad_fn=<NegBackward0>)
# tensor(1387.0750, grad_fn=<NegBackward0>)
# tensor(1387.0278, grad_fn=<NegBackward0>)
# tensor(1386.9659, grad_fn=<NegBackward0>)
# tensor(1386.9244, grad_fn=<NegBackward0>)
# tensor(1386.8738, grad_fn=<NegBackward0>)
# tensor(1386.8188, grad_fn=<NegBackward0>)
# tensor(1386.7736, grad_fn=<NegBackward0>)
# tensor(1386.7188, grad_fn=<NegBackward0>)
# tensor(1386.6736, grad_fn=<NegBackward0>)
# tensor(1386.6184, grad_fn=<NegBackward0>)
# tensor(1386.5725, grad_fn=<NegBackward0>)
# tensor(1386.5247, grad_fn=<NegBackward0>)
# tensor(1386.4723, grad_fn=<NegBackward0>)
# tensor(1386.4216, grad_fn=<NegBackward0>)
# tensor(1386.3688, grad_fn=<NegBackward0>)
# tensor(1386.3276, grad_fn=<NegBackward0>)
# tensor(1386.2693, grad_fn=<NegBackward0>)
# tensor(1386.2343, grad_fn=<NegBackward0>)
# tensor(1386.1829, grad_fn=<NegBackward0>)
# tensor(1386.1345, grad_fn=<NegBackward0>)
# tensor(1386.0870, grad_fn=<NegBackward0>)
# tensor(1386.0428, grad_fn=<NegBackward0>)
# tensor(1385.9839, grad_fn=<NegBackward0>)
# tensor(1385.9426, grad_fn=<NegBackward0>)
# tensor(1385.8937, grad_fn=<NegBackward0>)
# tensor(1385.8419, grad_fn=<NegBackward0>)
# tensor(1385.8064, grad_fn=<NegBackward0>)
# tensor(1385.7572, grad_fn=<NegBackward0>)
# tensor(1385.7092, grad_fn=<NegBackward0>)
# tensor(1385.6680, grad_fn=<NegBackward0>)
# tensor(1385.6265, grad_fn=<NegBackward0>)
# tensor(1385.5730, grad_fn=<NegBackward0>)
# tensor(1385.5354, grad_fn=<NegBackward0>)
# tensor(1385.4882, grad_fn=<NegBackward0>)
# tensor(1385.4430, grad_fn=<NegBackward0>)
# tensor(1385.3959, grad_fn=<NegBackward0>)
# tensor(1385.3508, grad_fn=<NegBackward0>)
# tensor(1385.3059, grad_fn=<NegBackward0>)
# tensor(1385.2712, grad_fn=<NegBackward0>)
# tensor(1385.2264, grad_fn=<NegBackward0>)
# tensor(1385.1716, grad_fn=<NegBackward0>)
# tensor(1385.1432, grad_fn=<NegBackward0>)
# tensor(1385.0999, grad_fn=<NegBackward0>)
# tensor(1385.0608, grad_fn=<NegBackward0>)
# tensor(1385.0052, grad_fn=<NegBackward0>)
# tensor(1384.9612, grad_fn=<NegBackward0>)
# tensor(1384.9290, grad_fn=<NegBackward0>)
# tensor(1384.8848, grad_fn=<NegBackward0>)
# tensor(1384.8452, grad_fn=<NegBackward0>)
# tensor(1384.8002, grad_fn=<NegBackward0>)
# tensor(1384.7542, grad_fn=<NegBackward0>)
# tensor(1384.7196, grad_fn=<NegBackward0>)
# tensor(1384.6711, grad_fn=<NegBackward0>)
# tensor(1384.6377, grad_fn=<NegBackward0>)
# tensor(1384.6000, grad_fn=<NegBackward0>)
# tensor(1384.5559, grad_fn=<NegBackward0>)
# tensor(1384.5140, grad_fn=<NegBackward0>)
# tensor(1384.4753, grad_fn=<NegBackward0>)
# tensor(1384.4221, grad_fn=<NegBackward0>)
# tensor(1384.4003, grad_fn=<NegBackward0>)
# tensor(1384.3619, grad_fn=<NegBackward0>)
# tensor(1384.3214, grad_fn=<NegBackward0>)
# tensor(1384.2832, grad_fn=<NegBackward0>)
# tensor(1384.2322, grad_fn=<NegBackward0>)
# tensor(1384.2036, grad_fn=<NegBackward0>)
# tensor(1384.1539, grad_fn=<NegBackward0>)
# tensor(1384.1279, grad_fn=<NegBackward0>)
# tensor(1384.0913, grad_fn=<NegBackward0>)
# tensor(1384.0627, grad_fn=<NegBackward0>)
# tensor(1384.0106, grad_fn=<NegBackward0>)
# tensor(1383.9725, grad_fn=<NegBackward0>)
# tensor(1383.9425, grad_fn=<NegBackward0>)
# tensor(1383.8987, grad_fn=<NegBackward0>)
# tensor(1383.8647, grad_fn=<NegBackward0>)
# tensor(1383.8357, grad_fn=<NegBackward0>)
# tensor(1383.7874, grad_fn=<NegBackward0>)
# tensor(1383.7592, grad_fn=<NegBackward0>)
# tensor(1383.7104, grad_fn=<NegBackward0>)
# tensor(1383.6923, grad_fn=<NegBackward0>)
# tensor(1383.6484, grad_fn=<NegBackward0>)
# tensor(1383.6062, grad_fn=<NegBackward0>)
# tensor(1383.5627, grad_fn=<NegBackward0>)
# tensor(1383.5229, grad_fn=<NegBackward0>)
# tensor(1383.4899, grad_fn=<NegBackward0>)
# tensor(1383.4564, grad_fn=<NegBackward0>)
# tensor(1383.4302, grad_fn=<NegBackward0>)
# tensor(1383.3848, grad_fn=<NegBackward0>)
# tensor(1383.3558, grad_fn=<NegBackward0>)
# tensor(1383.3240, grad_fn=<NegBackward0>)
# tensor(1383.2775, grad_fn=<NegBackward0>)
# tensor(1383.2478, grad_fn=<NegBackward0>)
# tensor(1383.2144, grad_fn=<NegBackward0>)
# tensor(1383.1644, grad_fn=<NegBackward0>)
# tensor(1383.1449, grad_fn=<NegBackward0>)
# tensor(1383.1050, grad_fn=<NegBackward0>)
# tensor(1383.0745, grad_fn=<NegBackward0>)
# tensor(1383.0286, grad_fn=<NegBackward0>)
# tensor(1382.9996, grad_fn=<NegBackward0>)
# tensor(1382.9661, grad_fn=<NegBackward0>)
# tensor(1382.9279, grad_fn=<NegBackward0>)
# tensor(1382.8917, grad_fn=<NegBackward0>)
# tensor(1382.8678, grad_fn=<NegBackward0>)
# tensor(1382.8257, grad_fn=<NegBackward0>)
# tensor(1382.8000, grad_fn=<NegBackward0>)
# tensor(1382.7605, grad_fn=<NegBackward0>)
# tensor(1382.7305, grad_fn=<NegBackward0>)
# tensor(1382.7097, grad_fn=<NegBackward0>)
# tensor(1382.6558, grad_fn=<NegBackward0>)
# tensor(1382.6309, grad_fn=<NegBackward0>)
# tensor(1382.5900, grad_fn=<NegBackward0>)
# tensor(1382.5624, grad_fn=<NegBackward0>)
# tensor(1382.5270, grad_fn=<NegBackward0>)
# tensor(1382.5044, grad_fn=<NegBackward0>)
# tensor(1382.4697, grad_fn=<NegBackward0>)
# tensor(1382.4409, grad_fn=<NegBackward0>)
# tensor(1382.3973, grad_fn=<NegBackward0>)
# tensor(1382.3737, grad_fn=<NegBackward0>)
# tensor(1382.3397, grad_fn=<NegBackward0>)
# tensor(1382.3162, grad_fn=<NegBackward0>)
# tensor(1382.2764, grad_fn=<NegBackward0>)
# tensor(1382.2480, grad_fn=<NegBackward0>)
# tensor(1382.2166, grad_fn=<NegBackward0>)
# tensor(1382.1835, grad_fn=<NegBackward0>)
# tensor(1382.1526, grad_fn=<NegBackward0>)
# tensor(1382.1173, grad_fn=<NegBackward0>)
# tensor(1382.0933, grad_fn=<NegBackward0>)
# tensor(1382.0613, grad_fn=<NegBackward0>)
# tensor(1382.0302, grad_fn=<NegBackward0>)
# tensor(1381.9985, grad_fn=<NegBackward0>)
# tensor(1381.9766, grad_fn=<NegBackward0>)
# tensor(1381.9409, grad_fn=<NegBackward0>)
# tensor(1381.8990, grad_fn=<NegBackward0>)
# tensor(1381.8846, grad_fn=<NegBackward0>)
# tensor(1381.8455, grad_fn=<NegBackward0>)
# tensor(1381.8267, grad_fn=<NegBackward0>)
# tensor(1381.7795, grad_fn=<NegBackward0>)
# tensor(1381.7560, grad_fn=<NegBackward0>)
# tensor(1381.7301, grad_fn=<NegBackward0>)
# tensor(1381.6986, grad_fn=<NegBackward0>)
# tensor(1381.6753, grad_fn=<NegBackward0>)
# tensor(1381.6454, grad_fn=<NegBackward0>)
# tensor(1381.6223, grad_fn=<NegBackward0>)
# tensor(1381.5909, grad_fn=<NegBackward0>)
# tensor(1381.5562, grad_fn=<NegBackward0>)
# tensor(1381.5383, grad_fn=<NegBackward0>)
# tensor(1381.5093, grad_fn=<NegBackward0>)
# tensor(1381.4725, grad_fn=<NegBackward0>)
# tensor(1381.4398, grad_fn=<NegBackward0>)
# tensor(1381.4108, grad_fn=<NegBackward0>)
# tensor(1381.3882, grad_fn=<NegBackward0>)
# tensor(1381.3634, grad_fn=<NegBackward0>)
# tensor(1381.3450, grad_fn=<NegBackward0>)
# tensor(1381.3032, grad_fn=<NegBackward0>)
# tensor(1381.2783, grad_fn=<NegBackward0>)
# tensor(1381.2479, grad_fn=<NegBackward0>)
# tensor(1381.2175, grad_fn=<NegBackward0>)
# tensor(1381.1985, grad_fn=<NegBackward0>)
# tensor(1381.1683, grad_fn=<NegBackward0>)
# tensor(1381.1228, grad_fn=<NegBackward0>)
# tensor(1381.0999, grad_fn=<NegBackward0>)
# tensor(1381.0630, grad_fn=<NegBackward0>)
# tensor(1381.0553, grad_fn=<NegBackward0>)
# tensor(1381.0325, grad_fn=<NegBackward0>)
# tensor(1380.9972, grad_fn=<NegBackward0>)
# tensor(1380.9551, grad_fn=<NegBackward0>)
# tensor(1380.9487, grad_fn=<NegBackward0>)
# tensor(1380.9208, grad_fn=<NegBackward0>)
# tensor(1380.8958, grad_fn=<NegBackward0>)
# tensor(1380.8726, grad_fn=<NegBackward0>)
# tensor(1380.8381, grad_fn=<NegBackward0>)
# tensor(1380.8108, grad_fn=<NegBackward0>)
# tensor(1380.7888, grad_fn=<NegBackward0>)
# tensor(1380.7621, grad_fn=<NegBackward0>)
# tensor(1380.7294, grad_fn=<NegBackward0>)
# tensor(1380.7029, grad_fn=<NegBackward0>)
# tensor(1380.6879, grad_fn=<NegBackward0>)
# tensor(1380.6545, grad_fn=<NegBackward0>)
# tensor(1380.6243, grad_fn=<NegBackward0>)
# tensor(1380.6005, grad_fn=<NegBackward0>)
# tensor(1380.5800, grad_fn=<NegBackward0>)
# tensor(1380.5614, grad_fn=<NegBackward0>)
# tensor(1380.5341, grad_fn=<NegBackward0>)
# tensor(1380.4886, grad_fn=<NegBackward0>)
# tensor(1380.4717, grad_fn=<NegBackward0>)
# tensor(1380.4489, grad_fn=<NegBackward0>)
# tensor(1380.4282, grad_fn=<NegBackward0>)
# tensor(1380.4041, grad_fn=<NegBackward0>)
# tensor(1380.3887, grad_fn=<NegBackward0>)
# tensor(1380.3521, grad_fn=<NegBackward0>)
# tensor(1380.3340, grad_fn=<NegBackward0>)
# tensor(1380.3086, grad_fn=<NegBackward0>)
# tensor(1380.2722, grad_fn=<NegBackward0>)
# tensor(1380.2551, grad_fn=<NegBackward0>)
# tensor(1380.2286, grad_fn=<NegBackward0>)
# tensor(1380.1995, grad_fn=<NegBackward0>)
# tensor(1380.1804, grad_fn=<NegBackward0>)
# tensor(1380.1519, grad_fn=<NegBackward0>)
# tensor(1380.1333, grad_fn=<NegBackward0>)
# tensor(1380.1010, grad_fn=<NegBackward0>)
# tensor(1380.0886, grad_fn=<NegBackward0>)
# tensor(1380.0599, grad_fn=<NegBackward0>)
# tensor(1380.0380, grad_fn=<NegBackward0>)
# tensor(1380.0143, grad_fn=<NegBackward0>)
# tensor(1379.9838, grad_fn=<NegBackward0>)
# tensor(1379.9606, grad_fn=<NegBackward0>)
# tensor(1379.9258, grad_fn=<NegBackward0>)
# tensor(1379.9058, grad_fn=<NegBackward0>)
# tensor(1379.8876, grad_fn=<NegBackward0>)
# tensor(1379.8551, grad_fn=<NegBackward0>)
# tensor(1379.8413, grad_fn=<NegBackward0>)
# tensor(1379.8123, grad_fn=<NegBackward0>)
# tensor(1379.7999, grad_fn=<NegBackward0>)
# tensor(1379.7635, grad_fn=<NegBackward0>)
# tensor(1379.7612, grad_fn=<NegBackward0>)
# tensor(1379.7341, grad_fn=<NegBackward0>)
# tensor(1379.7137, grad_fn=<NegBackward0>)
# tensor(1379.6716, grad_fn=<NegBackward0>)
# tensor(1379.6605, grad_fn=<NegBackward0>)
# tensor(1379.6328, grad_fn=<NegBackward0>)
# tensor(1379.6140, grad_fn=<NegBackward0>)
# tensor(1379.5903, grad_fn=<NegBackward0>)
# tensor(1379.5718, grad_fn=<NegBackward0>)
# tensor(1379.5350, grad_fn=<NegBackward0>)
# tensor(1379.5166, grad_fn=<NegBackward0>)
# tensor(1379.4968, grad_fn=<NegBackward0>)
# tensor(1379.4763, grad_fn=<NegBackward0>)
# tensor(1379.4548, grad_fn=<NegBackward0>)
# tensor(1379.4320, grad_fn=<NegBackward0>)
# tensor(1379.4093, grad_fn=<NegBackward0>)
# tensor(1379.3827, grad_fn=<NegBackward0>)
# tensor(1379.3685, grad_fn=<NegBackward0>)
# tensor(1379.3394, grad_fn=<NegBackward0>)
# tensor(1379.3252, grad_fn=<NegBackward0>)
# tensor(1379.3009, grad_fn=<NegBackward0>)
# tensor(1379.2717, grad_fn=<NegBackward0>)
# tensor(1379.2577, grad_fn=<NegBackward0>)
# tensor(1379.2291, grad_fn=<NegBackward0>)
# tensor(1379.2089, grad_fn=<NegBackward0>)
# tensor(1379.1897, grad_fn=<NegBackward0>)
# tensor(1379.1737, grad_fn=<NegBackward0>)
# tensor(1379.1593, grad_fn=<NegBackward0>)
# tensor(1379.1277, grad_fn=<NegBackward0>)
# tensor(1379.0967, grad_fn=<NegBackward0>)
# tensor(1379.0793, grad_fn=<NegBackward0>)
# tensor(1379.0566, grad_fn=<NegBackward0>)
# tensor(1379.0378, grad_fn=<NegBackward0>)
# tensor(1379.0210, grad_fn=<NegBackward0>)
# tensor(1379.0002, grad_fn=<NegBackward0>)
# tensor(1378.9716, grad_fn=<NegBackward0>)
# tensor(1378.9634, grad_fn=<NegBackward0>)
# tensor(1378.9270, grad_fn=<NegBackward0>)
# tensor(1378.9178, grad_fn=<NegBackward0>)
# tensor(1378.8901, grad_fn=<NegBackward0>)
# tensor(1378.8658, grad_fn=<NegBackward0>)
# tensor(1378.8533, grad_fn=<NegBackward0>)
# tensor(1378.8315, grad_fn=<NegBackward0>)
# tensor(1378.8076, grad_fn=<NegBackward0>)
# tensor(1378.8007, grad_fn=<NegBackward0>)
# tensor(1378.7721, grad_fn=<NegBackward0>)
# tensor(1378.7539, grad_fn=<NegBackward0>)
# tensor(1378.7358, grad_fn=<NegBackward0>)
# tensor(1378.7010, grad_fn=<NegBackward0>)
# tensor(1378.6826, grad_fn=<NegBackward0>)
# tensor(1378.6636, grad_fn=<NegBackward0>)
# tensor(1378.6479, grad_fn=<NegBackward0>)
# tensor(1378.6151, grad_fn=<NegBackward0>)
# tensor(1378.6001, grad_fn=<NegBackward0>)
# tensor(1378.5822, grad_fn=<NegBackward0>)
# tensor(1378.5709, grad_fn=<NegBackward0>)
# tensor(1378.5447, grad_fn=<NegBackward0>)
# tensor(1378.5259, grad_fn=<NegBackward0>)
# tensor(1378.5088, grad_fn=<NegBackward0>)
# tensor(1378.4904, grad_fn=<NegBackward0>)
# tensor(1378.4587, grad_fn=<NegBackward0>)
# tensor(1378.4424, grad_fn=<NegBackward0>)
# tensor(1378.4187, grad_fn=<NegBackward0>)
# tensor(1378.3906, grad_fn=<NegBackward0>)
# tensor(1378.3801, grad_fn=<NegBackward0>)
# tensor(1378.3594, grad_fn=<NegBackward0>)
# tensor(1378.3464, grad_fn=<NegBackward0>)
# tensor(1378.3279, grad_fn=<NegBackward0>)
# tensor(1378.3079, grad_fn=<NegBackward0>)
# tensor(1378.2908, grad_fn=<NegBackward0>)
# tensor(1378.2742, grad_fn=<NegBackward0>)
# tensor(1378.2450, grad_fn=<NegBackward0>)
# tensor(1378.2363, grad_fn=<NegBackward0>)
# tensor(1378.2112, grad_fn=<NegBackward0>)
# tensor(1378.1884, grad_fn=<NegBackward0>)
# tensor(1378.1770, grad_fn=<NegBackward0>)
# tensor(1378.1533, grad_fn=<NegBackward0>)
# tensor(1378.1384, grad_fn=<NegBackward0>)
# tensor(1378.1243, grad_fn=<NegBackward0>)
# tensor(1378.1002, grad_fn=<NegBackward0>)
# tensor(1378.0853, grad_fn=<NegBackward0>)
# tensor(1378.0555, grad_fn=<NegBackward0>)
# tensor(1378.0327, grad_fn=<NegBackward0>)
# tensor(1378.0233, grad_fn=<NegBackward0>)
# tensor(1377.9979, grad_fn=<NegBackward0>)
# tensor(1377.9869, grad_fn=<NegBackward0>)
# tensor(1377.9741, grad_fn=<NegBackward0>)
# tensor(1377.9559, grad_fn=<NegBackward0>)
# tensor(1377.9158, grad_fn=<NegBackward0>)
# tensor(1377.9116, grad_fn=<NegBackward0>)
# tensor(1377.8907, grad_fn=<NegBackward0>)
# tensor(1377.8779, grad_fn=<NegBackward0>)
# tensor(1377.8508, grad_fn=<NegBackward0>)
# tensor(1377.8308, grad_fn=<NegBackward0>)
# tensor(1377.8191, grad_fn=<NegBackward0>)
# tensor(1377.8055, grad_fn=<NegBackward0>)
# tensor(1377.7820, grad_fn=<NegBackward0>)
# tensor(1377.7778, grad_fn=<NegBackward0>)
# tensor(1377.7506, grad_fn=<NegBackward0>)
# tensor(1377.7347, grad_fn=<NegBackward0>)
# tensor(1377.7188, grad_fn=<NegBackward0>)
# tensor(1377.6958, grad_fn=<NegBackward0>)
# tensor(1377.6831, grad_fn=<NegBackward0>)
# tensor(1377.6639, grad_fn=<NegBackward0>)
# tensor(1377.6553, grad_fn=<NegBackward0>)
# tensor(1377.6304, grad_fn=<NegBackward0>)
# tensor(1377.6199, grad_fn=<NegBackward0>)
# tensor(1377.5817, grad_fn=<NegBackward0>)
# tensor(1377.5836, grad_fn=<NegBackward0>)
# tensor(1377.5701, grad_fn=<NegBackward0>)
# tensor(1377.5444, grad_fn=<NegBackward0>)
# tensor(1377.5249, grad_fn=<NegBackward0>)
# tensor(1377.5077, grad_fn=<NegBackward0>)
# tensor(1377.4835, grad_fn=<NegBackward0>)
# tensor(1377.4797, grad_fn=<NegBackward0>)
# tensor(1377.4586, grad_fn=<NegBackward0>)
# tensor(1377.4397, grad_fn=<NegBackward0>)
# tensor(1377.4261, grad_fn=<NegBackward0>)
# tensor(1377.3994, grad_fn=<NegBackward0>)
# tensor(1377.3958, grad_fn=<NegBackward0>)
# tensor(1377.3695, grad_fn=<NegBackward0>)
# tensor(1377.3660, grad_fn=<NegBackward0>)
# tensor(1377.3422, grad_fn=<NegBackward0>)
# tensor(1377.3203, grad_fn=<NegBackward0>)
# tensor(1377.3018, grad_fn=<NegBackward0>)
# tensor(1377.2896, grad_fn=<NegBackward0>)
# tensor(1377.2577, grad_fn=<NegBackward0>)
# tensor(1377.2539, grad_fn=<NegBackward0>)
# tensor(1377.2288, grad_fn=<NegBackward0>)
# tensor(1377.2183, grad_fn=<NegBackward0>)
# tensor(1377.2015, grad_fn=<NegBackward0>)
# tensor(1377.1841, grad_fn=<NegBackward0>)
# tensor(1377.2112, grad_fn=<NegBackward0>)
# tensor(1377.2288, grad_fn=<NegBackward0>)
# tensor(1377.1964, grad_fn=<NegBackward0>)
# tensor(1377.1761, grad_fn=<NegBackward0>)
# tensor(1377.1631, grad_fn=<NegBackward0>)
# tensor(1377.1523, grad_fn=<NegBackward0>)
# tensor(1377.1278, grad_fn=<NegBackward0>)
# tensor(1377.1053, grad_fn=<NegBackward0>)
# tensor(1377.1071, grad_fn=<NegBackward0>)
# tensor(1377.0830, grad_fn=<NegBackward0>)
# tensor(1377.0574, grad_fn=<NegBackward0>)
# tensor(1377.0436, grad_fn=<NegBackward0>)
# tensor(1377.0376, grad_fn=<NegBackward0>)
# tensor(1377.0164, grad_fn=<NegBackward0>)
# tensor(1376.9862, grad_fn=<NegBackward0>)
# tensor(1376.9879, grad_fn=<NegBackward0>)
# tensor(1376.9468, grad_fn=<NegBackward0>)
# tensor(1376.9518, grad_fn=<NegBackward0>)
# tensor(1376.9272, grad_fn=<NegBackward0>)
# tensor(1376.9207, grad_fn=<NegBackward0>)
# tensor(1376.9136, grad_fn=<NegBackward0>)
# tensor(1376.8762, grad_fn=<NegBackward0>)
# tensor(1376.8534, grad_fn=<NegBackward0>)
# tensor(1376.8500, grad_fn=<NegBackward0>)
# tensor(1376.8613, grad_fn=<NegBackward0>)
# tensor(1376.8154, grad_fn=<NegBackward0>)
# tensor(1376.8069, grad_fn=<NegBackward0>)
# tensor(1376.7841, grad_fn=<NegBackward0>)
# tensor(1376.7770, grad_fn=<NegBackward0>)
# tensor(1376.7771, grad_fn=<NegBackward0>)
# tensor(1376.7518, grad_fn=<NegBackward0>)
# tensor(1376.7329, grad_fn=<NegBackward0>)
# tensor(1376.7079, grad_fn=<NegBackward0>)
# tensor(1376.6875, grad_fn=<NegBackward0>)
# tensor(1376.6865, grad_fn=<NegBackward0>)
# tensor(1376.6843, grad_fn=<NegBackward0>)
# tensor(1376.6602, grad_fn=<NegBackward0>)
# tensor(1376.6423, grad_fn=<NegBackward0>)
# tensor(1376.6423, grad_fn=<NegBackward0>)
# tensor(1376.6238, grad_fn=<NegBackward0>)
# tensor(1376.5814, grad_fn=<NegBackward0>)
# tensor(1376.5754, grad_fn=<NegBackward0>)
# tensor(1376.5742, grad_fn=<NegBackward0>)
# tensor(1376.5461, grad_fn=<NegBackward0>)
# tensor(1376.5312, grad_fn=<NegBackward0>)
# tensor(1376.5315, grad_fn=<NegBackward0>)
# tensor(1376.5099, grad_fn=<NegBackward0>)
# tensor(1376.4792, grad_fn=<NegBackward0>)
# tensor(1376.4717, grad_fn=<NegBackward0>)
# tensor(1376.4711, grad_fn=<NegBackward0>)
# tensor(1376.4264, grad_fn=<NegBackward0>)
# tensor(1376.4381, grad_fn=<NegBackward0>)
# tensor(1376.4255, grad_fn=<NegBackward0>)
# tensor(1376.3972, grad_fn=<NegBackward0>)
# tensor(1376.3815, grad_fn=<NegBackward0>)
# tensor(1376.3743, grad_fn=<NegBackward0>)
# tensor(1376.3571, grad_fn=<NegBackward0>)
# tensor(1376.3267, grad_fn=<NegBackward0>)
# tensor(1376.3369, grad_fn=<NegBackward0>)
# tensor(1376.3192, grad_fn=<NegBackward0>)
# tensor(1376.2858, grad_fn=<NegBackward0>)
# tensor(1376.2749, grad_fn=<NegBackward0>)
# tensor(1376.2661, grad_fn=<NegBackward0>)
# tensor(1376.2523, grad_fn=<NegBackward0>)
# tensor(1376.2546, grad_fn=<NegBackward0>)
# tensor(1376.2285, grad_fn=<NegBackward0>)
# tensor(1376.2137, grad_fn=<NegBackward0>)
# tensor(1376.1912, grad_fn=<NegBackward0>)
# tensor(1376.1814, grad_fn=<NegBackward0>)
# tensor(1376.1565, grad_fn=<NegBackward0>)
# tensor(1376.1658, grad_fn=<NegBackward0>)
# tensor(1376.1359, grad_fn=<NegBackward0>)
# tensor(1376.1329, grad_fn=<NegBackward0>)
# tensor(1376.1086, grad_fn=<NegBackward0>)
# tensor(1376.0868, grad_fn=<NegBackward0>)
# tensor(1376.1035, grad_fn=<NegBackward0>)
# tensor(1376.0715, grad_fn=<NegBackward0>)
# tensor(1376.0524, grad_fn=<NegBackward0>)
# tensor(1376.0586, grad_fn=<NegBackward0>)
# tensor(1376.0468, grad_fn=<NegBackward0>)
# tensor(1376.0095, grad_fn=<NegBackward0>)
# tensor(1375.9937, grad_fn=<NegBackward0>)
# tensor(1375.9849, grad_fn=<NegBackward0>)
# tensor(1375.9917, grad_fn=<NegBackward0>)
# tensor(1375.9379, grad_fn=<NegBackward0>)
# tensor(1375.9338, grad_fn=<NegBackward0>)
# tensor(1375.9291, grad_fn=<NegBackward0>)
# tensor(1375.9181, grad_fn=<NegBackward0>)
# tensor(1375.9073, grad_fn=<NegBackward0>)
# tensor(1375.8933, grad_fn=<NegBackward0>)
# tensor(1375.8711, grad_fn=<NegBackward0>)
# tensor(1375.8582, grad_fn=<NegBackward0>)
# tensor(1375.8265, grad_fn=<NegBackward0>)
# tensor(1375.8408, grad_fn=<NegBackward0>)
# tensor(1375.8247, grad_fn=<NegBackward0>)
# tensor(1375.8057, grad_fn=<NegBackward0>)
# tensor(1375.7854, grad_fn=<NegBackward0>)
# tensor(1375.7883, grad_fn=<NegBackward0>)
# tensor(1375.7816, grad_fn=<NegBackward0>)
# tensor(1375.7638, grad_fn=<NegBackward0>)
# tensor(1375.7549, grad_fn=<NegBackward0>)
# tensor(1375.7285, grad_fn=<NegBackward0>)
# tensor(1375.7227, grad_fn=<NegBackward0>)
# tensor(1375.7034, grad_fn=<NegBackward0>)
# tensor(1375.6852, grad_fn=<NegBackward0>)
# tensor(1375.6630, grad_fn=<NegBackward0>)
# tensor(1375.6669, grad_fn=<NegBackward0>)
# tensor(1375.6592, grad_fn=<NegBackward0>)
# tensor(1375.6487, grad_fn=<NegBackward0>)
# tensor(1375.6417, grad_fn=<NegBackward0>)
# tensor(1375.6040, grad_fn=<NegBackward0>)
# tensor(1375.5920, grad_fn=<NegBackward0>)
# tensor(1375.5868, grad_fn=<NegBackward0>)
# tensor(1375.5530, grad_fn=<NegBackward0>)
# tensor(1375.5624, grad_fn=<NegBackward0>)
# tensor(1375.5618, grad_fn=<NegBackward0>)
# tensor(1375.5457, grad_fn=<NegBackward0>)
# tensor(1375.5184, grad_fn=<NegBackward0>)
# tensor(1375.5115, grad_fn=<NegBackward0>)
# tensor(1375.4998, grad_fn=<NegBackward0>)
# tensor(1375.4728, grad_fn=<NegBackward0>)
# tensor(1375.4781, grad_fn=<NegBackward0>)
# tensor(1375.4548, grad_fn=<NegBackward0>)
# tensor(1375.4688, grad_fn=<NegBackward0>)
# tensor(1375.4395, grad_fn=<NegBackward0>)
# tensor(1375.4200, grad_fn=<NegBackward0>)
# tensor(1375.4142, grad_fn=<NegBackward0>)
# tensor(1375.4130, grad_fn=<NegBackward0>)
# tensor(1375.3972, grad_fn=<NegBackward0>)
# tensor(1375.3616, grad_fn=<NegBackward0>)
# tensor(1375.3521, grad_fn=<NegBackward0>)
# tensor(1375.3539, grad_fn=<NegBackward0>)
# tensor(1375.3514, grad_fn=<NegBackward0>)
# tensor(1375.3164, grad_fn=<NegBackward0>)
# tensor(1375.3188, grad_fn=<NegBackward0>)
# tensor(1375.3060, grad_fn=<NegBackward0>)
# tensor(1375.2860, grad_fn=<NegBackward0>)
# tensor(1375.3000, grad_fn=<NegBackward0>)
# tensor(1375.2625, grad_fn=<NegBackward0>)
# tensor(1375.2440, grad_fn=<NegBackward0>)
# tensor(1375.2279, grad_fn=<NegBackward0>)
# tensor(1375.2122, grad_fn=<NegBackward0>)
# tensor(1375.2023, grad_fn=<NegBackward0>)
# tensor(1375.2029, grad_fn=<NegBackward0>)
# tensor(1375.1985, grad_fn=<NegBackward0>)
# tensor(1375.1921, grad_fn=<NegBackward0>)
# tensor(1375.1771, grad_fn=<NegBackward0>)
# tensor(1375.1509, grad_fn=<NegBackward0>)
# tensor(1375.1438, grad_fn=<NegBackward0>)
# tensor(1375.1487, grad_fn=<NegBackward0>)
# tensor(1375.1215, grad_fn=<NegBackward0>)
# tensor(1375.1011, grad_fn=<NegBackward0>)
# tensor(1375.0948, grad_fn=<NegBackward0>)
# tensor(1375.0835, grad_fn=<NegBackward0>)
# tensor(1375.0875, grad_fn=<NegBackward0>)
# tensor(1375.0736, grad_fn=<NegBackward0>)
# tensor(1375.0333, grad_fn=<NegBackward0>)
# tensor(1375.0303, grad_fn=<NegBackward0>)
# tensor(1375.0168, grad_fn=<NegBackward0>)
# tensor(1375.0238, grad_fn=<NegBackward0>)
# tensor(1375.0020, grad_fn=<NegBackward0>)
# tensor(1374.9963, grad_fn=<NegBackward0>)
# tensor(1374.9868, grad_fn=<NegBackward0>)
# tensor(1374.9570, grad_fn=<NegBackward0>)
# tensor(1374.9308, grad_fn=<NegBackward0>)
# tensor(1374.9453, grad_fn=<NegBackward0>)
# tensor(1374.9424, grad_fn=<NegBackward0>)
# tensor(1374.9174, grad_fn=<NegBackward0>)
# tensor(1374.8877, grad_fn=<NegBackward0>)
# tensor(1374.9021, grad_fn=<NegBackward0>)
# tensor(1374.8752, grad_fn=<NegBackward0>)
# tensor(1374.8638, grad_fn=<NegBackward0>)
# tensor(1374.8608, grad_fn=<NegBackward0>)
# tensor(1374.8645, grad_fn=<NegBackward0>)
# tensor(1374.8341, grad_fn=<NegBackward0>)
# tensor(1374.8137, grad_fn=<NegBackward0>)
# tensor(1374.8087, grad_fn=<NegBackward0>)
# tensor(1374.7830, grad_fn=<NegBackward0>)
# tensor(1374.7722, grad_fn=<NegBackward0>)
# tensor(1374.7590, grad_fn=<NegBackward0>)
# tensor(1374.7605, grad_fn=<NegBackward0>)
# tensor(1374.7522, grad_fn=<NegBackward0>)
# tensor(1374.7318, grad_fn=<NegBackward0>)
# tensor(1374.7056, grad_fn=<NegBackward0>)
# tensor(1374.7148, grad_fn=<NegBackward0>)
# tensor(1374.7015, grad_fn=<NegBackward0>)
# tensor(1374.6865, grad_fn=<NegBackward0>)
# tensor(1374.6749, grad_fn=<NegBackward0>)
# tensor(1374.6741, grad_fn=<NegBackward0>)
# tensor(1374.6710, grad_fn=<NegBackward0>)
# tensor(1374.6489, grad_fn=<NegBackward0>)
# tensor(1374.6232, grad_fn=<NegBackward0>)
# tensor(1374.6182, grad_fn=<NegBackward0>)
# tensor(1374.6200, grad_fn=<NegBackward0>)
# tensor(1374.5896, grad_fn=<NegBackward0>)
# tensor(1374.5811, grad_fn=<NegBackward0>)
# tensor(1374.5880, grad_fn=<NegBackward0>)
# tensor(1374.5784, grad_fn=<NegBackward0>)
# tensor(1374.5518, grad_fn=<NegBackward0>)
# tensor(1374.5393, grad_fn=<NegBackward0>)
# tensor(1374.5270, grad_fn=<NegBackward0>)
# tensor(1374.5233, grad_fn=<NegBackward0>)
# tensor(1374.5078, grad_fn=<NegBackward0>)
# tensor(1374.4816, grad_fn=<NegBackward0>)
# tensor(1374.5021, grad_fn=<NegBackward0>)
# tensor(1374.4893, grad_fn=<NegBackward0>)
# tensor(1374.4857, grad_fn=<NegBackward0>)
# tensor(1374.4612, grad_fn=<NegBackward0>)
# tensor(1374.4543, grad_fn=<NegBackward0>)
# tensor(1374.4287, grad_fn=<NegBackward0>)
# tensor(1374.4315, grad_fn=<NegBackward0>)
# tensor(1374.4108, grad_fn=<NegBackward0>)
# tensor(1374.4088, grad_fn=<NegBackward0>)
# tensor(1374.3929, grad_fn=<NegBackward0>)
# tensor(1374.3839, grad_fn=<NegBackward0>)
# tensor(1374.3738, grad_fn=<NegBackward0>)
# tensor(1374.3564, grad_fn=<NegBackward0>)
# tensor(1374.3293, grad_fn=<NegBackward0>)
# tensor(1374.3409, grad_fn=<NegBackward0>)
# tensor(1374.3179, grad_fn=<NegBackward0>)
# tensor(1374.3273, grad_fn=<NegBackward0>)
# tensor(1374.2942, grad_fn=<NegBackward0>)
# tensor(1374.3076, grad_fn=<NegBackward0>)
# tensor(1374.2708, grad_fn=<NegBackward0>)
# tensor(1374.2878, grad_fn=<NegBackward0>)
# tensor(1374.2753, grad_fn=<NegBackward0>)
# tensor(1374.2465, grad_fn=<NegBackward0>)
# tensor(1374.2571, grad_fn=<NegBackward0>)
# tensor(1374.2589, grad_fn=<NegBackward0>)
# tensor(1374.2290, grad_fn=<NegBackward0>)
# tensor(1374.2334, grad_fn=<NegBackward0>)
# tensor(1374.1956, grad_fn=<NegBackward0>)
# tensor(1374.2126, grad_fn=<NegBackward0>)
# tensor(1374.1694, grad_fn=<NegBackward0>)
# tensor(1374.1863, grad_fn=<NegBackward0>)
# tensor(1374.1604, grad_fn=<NegBackward0>)
# tensor(1374.1523, grad_fn=<NegBackward0>)
# tensor(1374.1299, grad_fn=<NegBackward0>)
# tensor(1374.1259, grad_fn=<NegBackward0>)
# tensor(1374.1104, grad_fn=<NegBackward0>)
# tensor(1374.1125, grad_fn=<NegBackward0>)
# tensor(1374.1116, grad_fn=<NegBackward0>)
# tensor(1374.0756, grad_fn=<NegBackward0>)
# tensor(1374.0887, grad_fn=<NegBackward0>)
# tensor(1374.0785, grad_fn=<NegBackward0>)
# tensor(1374.0546, grad_fn=<NegBackward0>)
# tensor(1374.0469, grad_fn=<NegBackward0>)
# tensor(1374.0221, grad_fn=<NegBackward0>)
# tensor(1374.0261, grad_fn=<NegBackward0>)
# tensor(1374.0122, grad_fn=<NegBackward0>)
# tensor(1374.0344, grad_fn=<NegBackward0>)
# tensor(1374.0072, grad_fn=<NegBackward0>)
# tensor(1373.9943, grad_fn=<NegBackward0>)
# tensor(1373.9785, grad_fn=<NegBackward0>)
# tensor(1373.9657, grad_fn=<NegBackward0>)
# tensor(1373.9740, grad_fn=<NegBackward0>)
# tensor(1373.9453, grad_fn=<NegBackward0>)
# tensor(1373.9437, grad_fn=<NegBackward0>)
# tensor(1373.9304, grad_fn=<NegBackward0>)
# tensor(1373.9148, grad_fn=<NegBackward0>)
# tensor(1373.9102, grad_fn=<NegBackward0>)
# tensor(1373.8923, grad_fn=<NegBackward0>)
# tensor(1373.8937, grad_fn=<NegBackward0>)
# tensor(1373.8903, grad_fn=<NegBackward0>)
# tensor(1373.8795, grad_fn=<NegBackward0>)
# tensor(1373.8624, grad_fn=<NegBackward0>)
# tensor(1373.8539, grad_fn=<NegBackward0>)
# tensor(1373.8409, grad_fn=<NegBackward0>)
# tensor(1373.8179, grad_fn=<NegBackward0>)
# tensor(1373.8159, grad_fn=<NegBackward0>)
# tensor(1373.7937, grad_fn=<NegBackward0>)
# tensor(1373.7791, grad_fn=<NegBackward0>)
# tensor(1373.7875, grad_fn=<NegBackward0>)
# tensor(1373.7695, grad_fn=<NegBackward0>)
# tensor(1373.7548, grad_fn=<NegBackward0>)
# tensor(1373.7562, grad_fn=<NegBackward0>)
# tensor(1373.7583, grad_fn=<NegBackward0>)
# tensor(1373.7317, grad_fn=<NegBackward0>)
# tensor(1373.7355, grad_fn=<NegBackward0>)
# tensor(1373.7120, grad_fn=<NegBackward0>)
# tensor(1373.7144, grad_fn=<NegBackward0>)
# tensor(1373.6995, grad_fn=<NegBackward0>)
# tensor(1373.6851, grad_fn=<NegBackward0>)
# tensor(1373.6732, grad_fn=<NegBackward0>)
# tensor(1373.6694, grad_fn=<NegBackward0>)
# tensor(1373.6630, grad_fn=<NegBackward0>)
# tensor(1373.6537, grad_fn=<NegBackward0>)
# tensor(1373.6425, grad_fn=<NegBackward0>)
# tensor(1373.6367, grad_fn=<NegBackward0>)
# tensor(1373.6350, grad_fn=<NegBackward0>)
# tensor(1373.6196, grad_fn=<NegBackward0>)
# tensor(1373.5931, grad_fn=<NegBackward0>)
# tensor(1373.5776, grad_fn=<NegBackward0>)
# tensor(1373.5857, grad_fn=<NegBackward0>)
# tensor(1373.6040, grad_fn=<NegBackward0>)
# tensor(1373.5662, grad_fn=<NegBackward0>)
# tensor(1373.5602, grad_fn=<NegBackward0>)
# tensor(1373.5293, grad_fn=<NegBackward0>)
# tensor(1373.5176, grad_fn=<NegBackward0>)
# tensor(1373.5410, grad_fn=<NegBackward0>)
# tensor(1373.5061, grad_fn=<NegBackward0>)
# tensor(1373.5017, grad_fn=<NegBackward0>)
# tensor(1373.5127, grad_fn=<NegBackward0>)
# tensor(1373.4863, grad_fn=<NegBackward0>)
# tensor(1373.4902, grad_fn=<NegBackward0>)
# tensor(1373.4717, grad_fn=<NegBackward0>)
# tensor(1373.4667, grad_fn=<NegBackward0>)
# tensor(1373.4438, grad_fn=<NegBackward0>)
# tensor(1373.4530, grad_fn=<NegBackward0>)
# tensor(1373.4213, grad_fn=<NegBackward0>)
# tensor(1373.4292, grad_fn=<NegBackward0>)
# tensor(1373.4155, grad_fn=<NegBackward0>)
# tensor(1373.4174, grad_fn=<NegBackward0>)
# tensor(1373.4138, grad_fn=<NegBackward0>)
# tensor(1373.3970, grad_fn=<NegBackward0>)
# tensor(1373.3822, grad_fn=<NegBackward0>)
# tensor(1373.3696, grad_fn=<NegBackward0>)
# tensor(1373.3611, grad_fn=<NegBackward0>)
# tensor(1373.3586, grad_fn=<NegBackward0>)
# tensor(1373.3274, grad_fn=<NegBackward0>)
# tensor(1373.3300, grad_fn=<NegBackward0>)
# tensor(1373.3213, grad_fn=<NegBackward0>)
# tensor(1373.3212, grad_fn=<NegBackward0>)
# tensor(1373.2855, grad_fn=<NegBackward0>)
# tensor(1373.3138, grad_fn=<NegBackward0>)
# tensor(1373.2971, grad_fn=<NegBackward0>)
# tensor(1373.2856, grad_fn=<NegBackward0>)
# tensor(1373.2755, grad_fn=<NegBackward0>)
# tensor(1373.2665, grad_fn=<NegBackward0>)
# tensor(1373.2483, grad_fn=<NegBackward0>)
# tensor(1373.2495, grad_fn=<NegBackward0>)
# tensor(1373.2290, grad_fn=<NegBackward0>)
# tensor(1373.2390, grad_fn=<NegBackward0>)
# tensor(1373.2155, grad_fn=<NegBackward0>)
# tensor(1373.2263, grad_fn=<NegBackward0>)
# tensor(1373.2092, grad_fn=<NegBackward0>)
# tensor(1373.2035, grad_fn=<NegBackward0>)
# tensor(1373.1814, grad_fn=<NegBackward0>)
# tensor(1373.1748, grad_fn=<NegBackward0>)
# tensor(1373.1708, grad_fn=<NegBackward0>)
# tensor(1373.1487, grad_fn=<NegBackward0>)
# tensor(1373.1476, grad_fn=<NegBackward0>)
# tensor(1373.1304, grad_fn=<NegBackward0>)
# tensor(1373.1362, grad_fn=<NegBackward0>)
# tensor(1373.1068, grad_fn=<NegBackward0>)
# tensor(1373.1084, grad_fn=<NegBackward0>)
# tensor(1373.1017, grad_fn=<NegBackward0>)
# tensor(1373.0858, grad_fn=<NegBackward0>)
# tensor(1373.0764, grad_fn=<NegBackward0>)
# tensor(1373.0647, grad_fn=<NegBackward0>)
# tensor(1373.0883, grad_fn=<NegBackward0>)
# tensor(1373.0475, grad_fn=<NegBackward0>)

# %%
torch.cat(LVemulator.Ls,axis=1).shape
# Out:
# torch.Size([10, 2002000])

# %%
plt.plot(torch.cat(LVemulator.Ls,axis=1).T[::1000],'o')
# Out:
# [<matplotlib.lines.Line2D at 0x28f629a90>,
#  <matplotlib.lines.Line2D at 0x28f62a190>,
#  <matplotlib.lines.Line2D at 0x28f628190>,
#  <matplotlib.lines.Line2D at 0x29ba18650>,
#  <matplotlib.lines.Line2D at 0x28f61d090>,
#  <matplotlib.lines.Line2D at 0x28f61ca10>,
#  <matplotlib.lines.Line2D at 0x28f61c4d0>,
#  <matplotlib.lines.Line2D at 0x28f61c210>,
#  <matplotlib.lines.Line2D at 0x28f61d4d0>,
#  <matplotlib.lines.Line2D at 0x28f61ccd0>]

# %%
XL_test = torch.cat((X_test,torch.repeat_interleave(LVemulator.L,p,dim=0)),axis=1)

# %%
LVemulator.L
# Out:
# tensor([[-1.5901, -0.4592],
#         [ 0.0226,  1.7138],
#         [-1.1303,  0.3376],
#         [-0.4170, -0.9256],
#         [ 0.5702,  0.2900],
#         [ 1.1163,  1.0931],
#         [ 0.9254, -1.3730],
#         [-0.0516, -1.2485],
#         [ 0.5657, -1.3967],
#         [-0.0112,  1.9683]], requires_grad=True)

# %%
plt.plot(torch.cat(LVemulator.lengths,axis=1).T[::1000],'o')
# Out:
# [<matplotlib.lines.Line2D at 0x3c7e7c090>,
#  <matplotlib.lines.Line2D at 0x34e1eba10>]

# %%
LVemulator.predict(XL_test)
# Out:
# tensor([0.9111, 4.0000, 4.0000], grad_fn=<CatBackward0>)
# tensor([0.7974, 4.0000, 4.0000], grad_fn=<CatBackward0>)
# (tensor([[ 1.9228e-01,  2.7504e-01],
#          [ 1.8828e-01,  1.6161e-01],
#          [ 1.9322e-01,  2.9653e-01],
#          [ 2.0279e-01, -2.1617e-01],
#          [ 2.1156e-01, -5.4520e-02],
#          [ 2.2839e-01,  7.2551e-01],
#          [ 2.1324e-01,  6.9228e-01],
#          [ 8.0623e-01,  3.2371e+00],
#          [ 2.0674e-01, -2.3669e-01],
#          [ 2.3856e-01,  1.0940e+00],
#          [ 4.7989e-01,  2.9175e+00],
#          [ 5.7390e-01,  2.7491e+00],
#          [ 2.0991e-01, -2.4189e-01],
#          [ 2.0692e-01,  1.7320e-01],
#          [ 3.6952e-01,  1.8942e+00],
#          [ 2.1028e-01,  4.8757e-05],
#          [ 2.1272e-01,  6.7847e-01],
#          [ 2.0941e-01,  5.7831e-01],
#          [ 3.4065e-01,  1.6594e+00],
#          [ 3.3320e-01,  1.8230e+00],
#          [ 6.0856e-01,  9.0850e-01],
#          [-4.8671e-01,  1.5501e-01],
#          [ 1.1463e+00,  1.3448e+00],
#          [-3.2674e-01,  2.8268e-01],
#          [ 5.8214e-01,  8.8540e-01],
#          [-8.0357e-02,  4.3198e-01],
#          [ 9.4114e-01,  1.2283e+00],
#          [ 3.5403e-01,  7.0306e-01],
#          [-4.3278e-01,  2.0189e-01],
#          [ 9.1439e-01,  1.2011e+00],
#          [ 7.6141e-03,  4.9003e-01],
#          [-8.2355e-02,  4.3089e-01],
#          [ 8.6978e-01,  1.1716e+00],
#          [-2.4838e-01,  3.1921e-01],
#          [ 1.2631e+00,  1.5632e+00],
#          [ 1.1722e+00,  1.4687e+00],
#          [-5.1143e-01,  1.3134e-01],
#          [ 9.5893e-02,  5.5512e-01],
#          [-2.8360e-02,  4.6426e-01],
#          [-1.5835e-01,  3.8749e-01],
#          [-4.1491e-01,  8.9882e-01],
#          [-5.5303e-01,  6.3794e-01],
#          [-6.9332e-01,  3.4973e-01],
#          [-2.8609e-01,  1.1806e+00],
#          [-7.5611e-01,  2.1768e-01],
#          [ 3.7553e-01,  2.5469e+00],
#          [ 8.2789e-01,  3.5545e+00],
#          [-5.1595e-01,  7.1297e-01],
#          [ 1.1474e-02,  1.7599e+00],
#          [-4.1837e-01,  9.1068e-01],
#          [-8.2764e-01,  6.1732e-02],
#          [ 3.5459e-01,  2.5210e+00],
#          [-3.6419e-01,  9.9828e-01],
#          [-7.2468e-01,  2.8540e-01],
#          [-7.3069e-01,  2.7166e-01],
#          [ 1.7679e-01,  2.1119e+00],
#          [-5.7616e-01,  5.9088e-01],
#          [ 5.5263e-01,  2.9175e+00],
#          [ 8.8356e-02,  1.9223e+00],
#          [ 8.6506e-02,  1.9603e+00],
#          [-3.8339e-01,  4.3803e-01],
#          [-4.7344e-01,  9.6273e-01],
#          [-3.8666e-01,  5.0139e-01],
#          [-4.3575e-01, -2.8330e-01],
#          [-4.1971e-01, -2.3340e-01],
#          [-3.9829e-01,  6.1542e-01],
#          [-4.0452e-01,  1.0867e-01],
#          [-4.7236e-01, -2.8024e-01],
#          [-3.8237e-01,  3.8357e-01],
#          [-3.9945e-01,  1.3882e-01],
#          [-4.7939e-01, -1.9306e-01],
#          [-4.7093e-01,  9.7254e-01],
#          [-4.6277e-01,  8.8966e-01],
#          [-4.5157e-01, -3.0254e-01],
#          [-4.4986e-01, -6.9555e-02],
#          [-4.6950e-01, -1.3670e-01],
#          [-4.9295e-01,  8.3217e-01],
#          [-4.3225e-01,  1.7444e-01],
#          [-4.0636e-01, -3.0801e-02],
#          [-3.9326e-01,  1.8465e-01],
#          [-6.5071e-01,  6.9554e-01],
#          [-7.4862e-01,  2.7893e-01],
#          [-5.9370e-01,  1.0414e+00],
#          [-8.1385e-01, -6.5437e-02],
#          [-8.3068e-01, -1.3509e-01],
#          [-7.0239e-01,  5.2357e-01],
#          [-4.8485e-01,  1.8821e+00],
#          [-5.3444e-01,  1.5424e+00],
#          [-5.3896e-01,  1.5119e+00],
#          [-7.5947e-01,  1.6680e-01],
#          [-8.1074e-01, -2.8294e-02],
#          [-5.3579e-01,  1.5339e+00],
#          [-6.7844e-01,  5.4838e-01],
#          [-5.7706e-01,  1.1573e+00],
#          [-4.5972e-01,  2.3092e+00],
#          [-8.3843e-01, -1.6670e-01],
#          [-3.7362e-01,  2.6923e+00],
#          [-7.4313e-01,  3.0752e-01],
#          [-4.8464e-01,  2.0032e+00],
#          [-8.4048e-01, -1.7184e-01],
#          [ 9.0754e-02,  2.6448e-01],
#          [ 1.5289e-02,  8.0331e-01],
#          [ 4.8065e-02,  8.1519e-01],
#          [ 2.1099e-01, -3.6036e-01],
#          [-2.3643e-01,  3.2650e+00],
#          [-5.5746e-02,  1.6386e+00],
#          [ 2.0026e-01, -3.1159e-01],
#          [-1.8447e-02,  1.1196e+00],
#          [-8.0916e-02,  1.9234e+00],
#          [-1.0823e-01,  2.0596e+00],
#          [-1.1813e-01,  2.1399e+00],
#          [ 9.0411e-02,  2.6651e-01],
#          [-1.2176e-01,  2.9759e+00],
#          [-2.5547e-01,  3.5570e+00],
#          [ 1.4347e-01,  5.4775e-02],
#          [-1.2178e-01,  3.0191e+00],
#          [-1.2011e-01,  2.8521e+00],
#          [-2.1997e-01,  3.0729e+00],
#          [ 1.4281e-01,  5.9458e-02],
#          [-2.1431e-01,  3.0106e+00],
#          [-1.0599e+00, -6.3509e-01],
#          [-1.2276e-01, -8.8639e-01],
#          [-2.1920e+00, -3.5205e-01],
#          [-2.0078e-01, -8.4868e-01],
#          [-3.6955e-01, -8.0431e-01],
#          [-6.4190e-01, -7.3962e-01],
#          [-2.1077e-01, -8.6042e-01],
#          [-1.6579e+00, -4.7642e-01],
#          [-1.2434e+00, -5.8637e-01],
#          [-1.0328e-01, -8.8368e-01],
#          [-7.6773e-01, -7.0917e-01],
#          [-7.1608e-01, -7.1904e-01],
#          [-8.9950e-01, -6.7650e-01],
#          [-1.9368e+00, -4.3624e-01],
#          [-1.2614e+00, -5.9608e-01],
#          [-1.1364e+00, -6.2371e-01],
#          [-1.0045e+00, -6.4940e-01],
#          [-9.6725e-01, -6.5910e-01],
#          [-1.3761e-01, -8.8242e-01],
#          [-6.0442e-01, -7.4859e-01],
#          [-4.6246e-01, -4.6402e-01],
#          [-1.2859e+00, -1.9508e-01],
#          [-3.2570e-01, -4.8343e-01],
#          [-1.2776e+00, -2.9593e-01],
#          [-3.7168e-01, -4.7348e-01],
#          [-4.1185e-01, -4.6828e-01],
#          [-7.7114e-01, -4.3205e-01],
#          [-7.1622e-01, -4.4133e-01],
#          [-2.8646e-01, -4.9340e-01],
#          [-1.0718e+00, -3.3836e-01],
#          [-3.0409e-01, -4.8190e-01],
#          [-6.3005e-01, -5.0929e-01],
#          [-1.1020e+00, -3.6965e-01],
#          [-4.7168e-01, -4.6342e-01],
#          [-6.2683e-01, -5.0909e-01],
#          [-6.1541e-01, -5.0830e-01],
#          [-1.1819e+00, -3.3525e-01],
#          [-1.0166e+00, -4.0711e-01],
#          [-3.9262e-01, -4.6035e-01],
#          [-2.7472e-01, -5.0451e-01],
#          [-1.8613e+00, -6.4173e-01],
#          [-7.6545e-01, -7.2269e-01],
#          [-2.1791e+00, -6.5279e-01],
#          [-6.6606e-01, -7.1072e-01],
#          [-1.8598e-01, -7.4456e-01],
#          [-2.6794e-01, -7.4447e-01],
#          [-1.3916e+00, -7.0512e-01],
#          [-1.8520e+00, -6.4294e-01],
#          [-1.8949e+00, -6.3701e-01],
#          [-2.0754e-01, -7.5360e-01],
#          [-2.1741e+00, -6.5298e-01],
#          [-1.0123e+00, -7.2305e-01],
#          [-7.0823e-01, -7.0962e-01],
#          [-8.3203e-01, -7.2388e-01],
#          [-2.1185e+00, -6.5478e-01],
#          [-2.5562e-01, -7.4642e-01],
#          [-2.1123e+00, -6.5491e-01],
#          [-2.0510e-01, -7.5389e-01],
#          [-1.9226e-01, -7.4175e-01],
#          [-2.4712e+00, -6.5504e-01],
#          [-1.0990e-01,  1.2810e-01],
#          [ 7.8386e-01,  2.8793e-01],
#          [-6.6458e-02,  9.8311e-02],
#          [ 5.4574e-01,  1.9061e-01],
#          [ 5.7002e-01,  2.8002e-01],
#          [ 8.2349e-02,  1.1724e-01],
#          [-1.1767e-01,  1.2763e-01],
#          [ 1.1119e+00,  4.9491e-01],
#          [-4.4506e-01,  1.8894e-02],
#          [ 9.0320e-02,  1.1883e-01],
#          [-4.5670e-01,  3.1205e-03],
#          [ 3.0133e-01,  1.4130e-01],
#          [ 5.6728e-01,  1.9734e-01],
#          [ 2.5224e-01,  1.5925e-01],
#          [ 6.4943e-01,  2.2686e-01],
#          [ 6.5914e-01,  3.1951e-01],
#          [-3.9825e-01,  4.1965e-02],
#          [-2.6147e-01,  8.9544e-02],
#          [-1.1719e-01,  9.5322e-02],
#          [ 1.2892e+00,  6.3296e-01]], grad_fn=<CopySlices>),
#  tensor([[0.0066, 0.0143],
#          [0.0067, 0.0144],
#          [0.0066, 0.0143],
#          [0.0071, 0.0154],
#          [0.0072, 0.0157],
#          [0.0065, 0.0140],
#          [0.0068, 0.0145],
#          [0.0134, 0.0310],
#          [0.0071, 0.0155],
#          [0.0066, 0.0140],
#          [0.0078, 0.0170],
#          [0.0088, 0.0192],
#          [0.0071, 0.0156],
#          [0.0072, 0.0158],
#          [0.0073, 0.0160],
#          [0.0072, 0.0158],
#          [0.0068, 0.0145],
#          [0.0068, 0.0148],
#          [0.0070, 0.0153],
#          [0.0068, 0.0147],
#          [0.0068, 0.0150],
#          [0.0062, 0.0133],
#          [0.0081, 0.0173],
#          [0.0063, 0.0135],
#          [0.0068, 0.0149],
#          [0.0062, 0.0134],
#          [0.0068, 0.0148],
#          [0.0065, 0.0139],
#          [0.0066, 0.0141],
#          [0.0068, 0.0149],
#          [0.0065, 0.0140],
#          [0.0062, 0.0134],
#          [0.0066, 0.0141],
#          [0.0066, 0.0142],
#          [0.0073, 0.0156],
#          [0.0068, 0.0145],
#          [0.0062, 0.0133],
#          [0.0065, 0.0139],
#          [0.0065, 0.0141],
#          [0.0063, 0.0135],
#          [0.0069, 0.0150],
#          [0.0073, 0.0164],
#          [0.0067, 0.0143],
#          [0.0069, 0.0152],
#          [0.0070, 0.0150],
#          [0.0075, 0.0161],
#          [0.0090, 0.0196],
#          [0.0073, 0.0164],
#          [0.0071, 0.0155],
#          [0.0072, 0.0161],
#          [0.0068, 0.0147],
#          [0.0064, 0.0136],
#          [0.0069, 0.0151],
#          [0.0067, 0.0143],
#          [0.0070, 0.0152],
#          [0.0073, 0.0157],
#          [0.0073, 0.0164],
#          [0.0065, 0.0140],
#          [0.0072, 0.0155],
#          [0.0064, 0.0135],
#          [0.0064, 0.0136],
#          [0.0072, 0.0155],
#          [0.0064, 0.0135],
#          [0.0063, 0.0136],
#          [0.0062, 0.0132],
#          [0.0064, 0.0137],
#          [0.0066, 0.0145],
#          [0.0064, 0.0138],
#          [0.0064, 0.0137],
#          [0.0066, 0.0144],
#          [0.0063, 0.0133],
#          [0.0073, 0.0156],
#          [0.0076, 0.0164],
#          [0.0064, 0.0140],
#          [0.0065, 0.0141],
#          [0.0064, 0.0136],
#          [0.0070, 0.0153],
#          [0.0064, 0.0136],
#          [0.0062, 0.0133],
#          [0.0066, 0.0142],
#          [0.0068, 0.0148],
#          [0.0066, 0.0141],
#          [0.0069, 0.0149],
#          [0.0062, 0.0132],
#          [0.0062, 0.0131],
#          [0.0067, 0.0144],
#          [0.0070, 0.0152],
#          [0.0070, 0.0151],
#          [0.0070, 0.0151],
#          [0.0064, 0.0138],
#          [0.0064, 0.0136],
#          [0.0070, 0.0151],
#          [0.0067, 0.0147],
#          [0.0069, 0.0149],
#          [0.0072, 0.0155],
#          [0.0062, 0.0132],
#          [0.0073, 0.0158],
#          [0.0066, 0.0142],
#          [0.0071, 0.0151],
#          [0.0062, 0.0133],
#          [0.0074, 0.0165],
#          [0.0075, 0.0167],
#          [0.0067, 0.0145],
#          [0.0067, 0.0144],
#          [0.0076, 0.0162],
#          [0.0066, 0.0142],
#          [0.0066, 0.0143],
#          [0.0073, 0.0160],
#          [0.0076, 0.0161],
#          [0.0067, 0.0143],
#          [0.0067, 0.0143],
#          [0.0074, 0.0165],
#          [0.0224, 0.0544],
#          [0.0091, 0.0196],
#          [0.0067, 0.0146],
#          [0.0263, 0.0647],
#          [0.0166, 0.0394],
#          [0.0072, 0.0154],
#          [0.0067, 0.0146],
#          [0.0071, 0.0152],
#          [0.0067, 0.0144],
#          [0.0075, 0.0167],
#          [0.0075, 0.0162],
#          [0.0068, 0.0147],
#          [0.0065, 0.0139],
#          [0.0064, 0.0138],
#          [0.0072, 0.0158],
#          [0.0072, 0.0157],
#          [0.0069, 0.0148],
#          [0.0073, 0.0162],
#          [0.0065, 0.0139],
#          [0.0064, 0.0138],
#          [0.0064, 0.0137],
#          [0.0064, 0.0137],
#          [0.0064, 0.0137],
#          [0.0064, 0.0137],
#          [0.0066, 0.0143],
#          [0.0066, 0.0142],
#          [0.0074, 0.0166],
#          [0.0064, 0.0137],
#          [0.0062, 0.0132],
#          [0.0082, 0.0177],
#          [0.0060, 0.0128],
#          [0.0077, 0.0168],
#          [0.0061, 0.0129],
#          [0.0061, 0.0130],
#          [0.0064, 0.0137],
#          [0.0064, 0.0137],
#          [0.0065, 0.0140],
#          [0.0067, 0.0143],
#          [0.0065, 0.0139],
#          [0.0067, 0.0146],
#          [0.0065, 0.0138],
#          [0.0062, 0.0133],
#          [0.0067, 0.0146],
#          [0.0067, 0.0146],
#          [0.0068, 0.0144],
#          [0.0064, 0.0136],
#          [0.0063, 0.0135],
#          [0.0062, 0.0134],
#          [0.0063, 0.0134],
#          [0.0063, 0.0133],
#          [0.0063, 0.0133],
#          [0.0062, 0.0132],
#          [0.0066, 0.0144],
#          [0.0063, 0.0136],
#          [0.0065, 0.0141],
#          [0.0063, 0.0134],
#          [0.0063, 0.0134],
#          [0.0065, 0.0142],
#          [0.0063, 0.0133],
#          [0.0064, 0.0137],
#          [0.0062, 0.0132],
#          [0.0063, 0.0135],
#          [0.0063, 0.0133],
#          [0.0064, 0.0137],
#          [0.0063, 0.0133],
#          [0.0066, 0.0142],
#          [0.0066, 0.0144],
#          [0.0077, 0.0169],
#          [0.0068, 0.0146],
#          [0.0077, 0.0171],
#          [0.0069, 0.0149],
#          [0.0075, 0.0163],
#          [0.0065, 0.0138],
#          [0.0068, 0.0147],
#          [0.0067, 0.0146],
#          [0.0075, 0.0163],
#          [0.0065, 0.0139],
#          [0.0068, 0.0147],
#          [0.0064, 0.0136],
#          [0.0070, 0.0151],
#          [0.0075, 0.0164],
#          [0.0066, 0.0143],
#          [0.0076, 0.0168],
#          [0.0065, 0.0139],
#          [0.0063, 0.0135],
#          [0.0069, 0.0149],
#          [0.0069, 0.0149],
#          [0.0079, 0.0167]], grad_fn=<CopySlices>))

# %%
LVemulator.lengthscale
# Out:
# tensor([[0.9111],
#         [0.7974]], requires_grad=True)

# %%
LVemulator.scale
# Out:
# tensor([11.1841, 11.3084], requires_grad=True)

# %%
LVemulator.MSE(XL_test,Y_test)
# Out:
# tensor([0.9111, 4.0000, 4.0000], grad_fn=<CatBackward0>)
# tensor([0.7974, 4.0000, 4.0000], grad_fn=<CatBackward0>)
# tensor([0.0044, 0.0081], grad_fn=<MeanBackward1>)

# %%
LVemulator.R2(XL_test,Y_test)
# Out:
# tensor([0.9111, 4.0000, 4.0000], grad_fn=<CatBackward0>)
# tensor([0.7974, 4.0000, 4.0000], grad_fn=<CatBackward0>)
# tensor([0.9901, 0.9931], grad_fn=<RsubBackward1>)

# %%
Y_test.std(axis=0)
# Out:
# tensor([0.9837, 1.0331])

# %%
Y_test
# Out:
# tensor([[-1.0250, -1.0250],
#         [-0.4678, -0.4678],
#         [-2.2169, -2.2169],
#         [-2.2122, -2.2122],
#         [-2.0013, -2.0013],
#         [-2.2786, -2.2786],
#         [-1.3610, -1.3610],
#         [-1.1209, -1.1209],
#         [-0.5388, -0.5388],
#         [-1.1221, -1.1221],
#         [-2.9212, -2.9212],
#         [-3.0488, -3.0488],
#         [-0.7269, -0.7269],
#         [-0.4919, -0.4919],
#         [-0.9623, -0.9623],
#         [-1.1929, -1.1929],
#         [-1.8205, -1.8205],
#         [-0.5970, -0.5970],
#         [-2.6006, -2.6006],
#         [-1.6971, -1.6971],
#         [-2.5839, -2.5839],
#         [ 0.2603,  0.2603],
#         [-0.4646, -0.4646],
#         [-0.0280, -0.0280],
#         [-0.1094, -0.1094],
#         [ 0.2439,  0.2439],
#         [-1.8135, -1.8135],
#         [-1.9327, -1.9327],
#         [-0.1334, -0.1334],
#         [ 0.3693,  0.3693],
#         [ 0.2954,  0.2954],
#         [ 0.2304,  0.2304],
#         [-2.5414, -2.5414],
#         [-1.0739, -1.0739],
#         [-1.7298, -1.7298],
#         [-2.9119, -2.9119],
#         [-2.7795, -2.7795],
#         [-3.3164, -3.3164],
#         [-1.4943, -1.4943],
#         [-1.7498, -1.7498],
#         [ 0.0595,  0.0595],
#         [ 0.4771,  0.4771],
#         [ 0.8389,  0.8389],
#         [ 1.4419,  1.4419],
#         [ 1.4381,  1.4381],
#         [ 0.1525,  0.1525],
#         [ 0.2625,  0.2625],
#         [ 0.7138,  0.7138],
#         [ 0.2073,  0.2073],
#         [ 1.1363,  1.1363],
#         [ 0.3367,  0.3366],
#         [ 1.5590,  1.5590],
#         [ 1.5141,  1.5141],
#         [ 0.0419,  0.0419],
#         [ 0.1723,  0.1723],
#         [ 0.9285,  0.9285],
#         [ 0.7952,  0.7952],
#         [ 0.0982,  0.0982],
#         [ 0.9676,  0.9676],
#         [ 0.2514,  0.2514],
#         [ 0.7445,  0.7445],
#         [-0.0490, -0.0489],
#         [ 0.4702,  0.4702],
#         [ 0.9022,  0.9022],
#         [ 2.3807,  2.3807],
#         [ 2.5720,  2.5720],
#         [ 1.9903,  1.9904],
#         [-0.1045, -0.1045],
#         [ 0.6305,  0.6305],
#         [ 0.8558,  0.8558],
#         [ 0.0185,  0.0185],
#         [-0.1494, -0.1494],
#         [ 0.4832,  0.4832],
#         [ 2.8915,  2.8915],
#         [ 1.4360,  1.4360],
#         [ 2.1939,  2.1939],
#         [ 0.2785,  0.2785],
#         [ 0.0359,  0.0359],
#         [ 1.0449,  1.0450],
#         [-0.0831, -0.0831],
#         [ 0.5383,  0.5383],
#         [ 0.5159,  0.5159],
#         [ 0.5055,  0.5055],
#         [ 0.5352,  0.5352],
#         [ 0.5094,  0.5094],
#         [ 0.3385,  0.3385],
#         [ 0.4432,  0.4432],
#         [ 0.3937,  0.3937],
#         [ 0.5316,  0.5316],
#         [ 0.5046,  0.5046],
#         [ 0.5198,  0.5198],
#         [ 0.4198,  0.4199],
#         [ 0.4963,  0.4963],
#         [ 0.5269,  0.5269],
#         [ 0.5244,  0.5244],
#         [ 0.4050,  0.4050],
#         [ 0.4947,  0.4947],
#         [ 0.4918,  0.4918],
#         [ 0.5022,  0.5022],
#         [ 0.5397,  0.5397],
#         [ 0.1168,  0.1168],
#         [ 0.0092,  0.0092],
#         [ 0.1422,  0.1422],
#         [-0.1053, -0.1053],
#         [ 0.1482,  0.1482],
#         [ 0.1421,  0.1421],
#         [ 0.2134,  0.2134],
#         [ 0.0111,  0.0111],
#         [-0.1304, -0.1304],
#         [-0.0680, -0.0680],
#         [ 0.2205,  0.2205],
#         [-0.0253, -0.0253],
#         [ 0.2154,  0.2154],
#         [ 0.1986,  0.1986],
#         [-0.0127, -0.0127],
#         [ 0.1554,  0.1554],
#         [-0.0634, -0.0634],
#         [ 0.2096,  0.2096],
#         [-0.0251, -0.0251],
#         [ 0.0499,  0.0499],
#         [ 0.2934,  0.2934],
#         [-0.2520, -0.2520],
#         [ 0.0534,  0.0533],
#         [ 0.2251,  0.2251],
#         [ 0.2314,  0.2314],
#         [ 0.0377,  0.0377],
#         [ 0.0323,  0.0323],
#         [-0.3298, -0.3298],
#         [-0.7375, -0.7375],
#         [-0.2234, -0.2234],
#         [ 0.0341,  0.0341],
#         [ 0.2951,  0.2951],
#         [ 0.2078,  0.2078],
#         [-0.5480, -0.5480],
#         [-0.2766, -0.2766],
#         [-0.4919, -0.4919],
#         [ 0.1060,  0.1060],
#         [ 0.2730,  0.2730],
#         [-0.4477, -0.4477],
#         [-0.2699, -0.2699],
#         [ 0.6135,  0.6134],
#         [ 0.6080,  0.6080],
#         [ 0.6407,  0.6407],
#         [ 0.5964,  0.5964],
#         [ 0.7697,  0.7697],
#         [ 0.6343,  0.6343],
#         [ 0.6348,  0.6348],
#         [ 0.6060,  0.6060],
#         [ 0.6160,  0.6160],
#         [ 0.6533,  0.6533],
#         [ 0.6040,  0.6040],
#         [ 0.6294,  0.6294],
#         [ 0.7162,  0.7162],
#         [ 0.7120,  0.7120],
#         [ 0.6199,  0.6199],
#         [ 0.6691,  0.6691],
#         [ 0.7148,  0.7148],
#         [ 0.6311,  0.6311],
#         [ 0.7306,  0.7306],
#         [ 0.6292,  0.6293],
#         [ 0.5467,  0.5467],
#         [ 0.6690,  0.6690],
#         [-0.5862, -0.5862],
#         [ 0.6483,  0.6483],
#         [ 0.3546,  0.3546],
#         [-0.5306, -0.5306],
#         [ 0.6182,  0.6182],
#         [ 0.5275,  0.5275],
#         [-0.1517, -0.1517],
#         [ 0.1673,  0.1673],
#         [ 0.3516,  0.3516],
#         [ 0.6660,  0.6660],
#         [ 0.4816,  0.4816],
#         [ 0.4645,  0.4645],
#         [ 0.6751,  0.6751],
#         [ 0.0842,  0.0842],
#         [-0.2743, -0.2743],
#         [-0.4742, -0.4742],
#         [ 0.5495,  0.5495],
#         [ 0.5639,  0.5639],
#         [ 0.1594,  0.1594],
#         [ 0.1499,  0.1498],
#         [ 0.1593,  0.1593],
#         [ 0.1578,  0.1578],
#         [ 0.1567,  0.1567],
#         [ 0.1594,  0.1594],
#         [ 0.1586,  0.1586],
#         [ 0.1545,  0.1545],
#         [ 0.1592,  0.1592],
#         [ 0.1595,  0.1595],
#         [ 0.1575,  0.1575],
#         [ 0.1555,  0.1555],
#         [ 0.1590,  0.1590],
#         [ 0.1503,  0.1503],
#         [ 0.1594,  0.1594],
#         [ 0.1594,  0.1594],
#         [ 0.1595,  0.1595],
#         [ 0.1559,  0.1559],
#         [ 0.1590,  0.1590],
#         [ 0.1592,  0.1592]])

# %%
for param_name, param in emulator.models[0].named_parameters():
    print(f'Parameter name: {param_name:42} ')
# Out:
# Parameter name: likelihood.noise_covar.raw_noise
# Parameter name: covar_module.raw_outputscale
# Parameter name: covar_module.base_kernel.raw_lengthscale

# %%
emulator.models[0].covar_module.outputscale
emulator.models[0].covar_module.base_kernel.lengthscale
# Out:
# tensor([[ 1.9199,  4.0153, 32.0411]], grad_fn=<SoftplusBackward0>)

# %%
emulator.models[0].covar_module.outputscale.detach().clone()
# Out:
# tensor(45.1826)

# %%
rbf(X_all_train,X_all_train,1.,torch.tensor(1.))
# Out:
# tensor([[1.0000, 0.4176, 0.8276,  ..., 0.0959, 0.0387, 0.0927],
#         [0.4176, 1.0000, 0.1533,  ..., 0.0102, 0.1527, 0.1589],
#         [0.8276, 0.1533, 1.0000,  ..., 0.1502, 0.0113, 0.0397],
#         ...,
#         [0.0959, 0.0102, 0.1502,  ..., 1.0000, 0.0237, 0.1092],
#         [0.0387, 0.1527, 0.0113,  ..., 0.0237, 1.0000, 0.8195],
#         [0.0927, 0.1589, 0.0397,  ..., 0.1092, 0.8195, 1.0000]])

# %%
rbf(X_all_train,X_all_train,1.,torch.tensor(1.))-rbf2(X_all_train,X_all_train,1.,torch.tensor(1.))
# Out:
# tensor([[ 0.0000e+00,  2.4321e-01,  1.4268e-01,  ...,  8.6730e-02,
#           3.7205e-02,  8.4092e-02],
#         [ 2.4321e-01,  0.0000e+00,  1.2979e-01,  ...,  1.0086e-02,
#           1.2941e-01,  1.3365e-01],
#         [ 1.4268e-01,  1.2979e-01, -4.7684e-07,  ...,  1.2761e-01,
#           1.1132e-02,  3.8166e-02],
#         ...,
#         [ 8.6730e-02,  1.0086e-02,  1.2761e-01,  ...,  0.0000e+00,
#           2.3156e-02,  9.7266e-02],
#         [ 3.7205e-02,  1.2941e-01,  1.1132e-02,  ...,  2.3156e-02,
#           0.0000e+00,  1.4790e-01],
#         [ 8.4092e-02,  1.3365e-01,  3.8166e-02,  ...,  9.7266e-02,
#           1.4790e-01,  0.0000e+00]])

# %%
plt.imshow(rbf(X_all_train,X_all_train,1.,torch.tensor(1.))-rbf2(X_all_train,X_all_train,1.,torch.tensor(1.)))

# %%
plt.imshow(rbf2(X_all_train,X_all_train,1.,torch.tensor(1.)))

# %%
emulator.R2(X_all_test,Y_test)
# Out:
# tensor([1.0000, 1.0000], grad_fn=<RsubBackward1>)

# %%
def cost(y,XL,scaling1,lengthscale1,scaling2,lengthscale2,sigma2,L_dim,mean=0):
    
    K1=rbf(XL,XL,scaling1,lengthscale1)+sigma2*torch.eye(XL.shape[0])
    K2=rbf(XL,XL,scaling2,lengthscale2)+sigma2*torch.eye(XL.shape[0])
    #K_inv=torch.kron(torch.linalg.inv(K_x),torch.linalg.inv(K_L))
    #K_inv=torch.kron(torch.linalg.inv(K_L),torch.linalg.inv(K_x))
    #print(torch.linalg.det(K))
    c = multivariate_ll(y[:,[0]],mean,K1) + multivariate_ll(y[:,[1]],mean,K2)+ multivariate_ll(XL[:,L_dim:],0,torch.eye(XL.shape[0])) # multivariate_ll(torch.repeat_interleave(L,x.shape[0])[:,None],0,torch.eye(inp.shape[0]))
    return -c

# %%
L = torch.rand(L_true.shape[0],L_true.shape[1]).clone().detach().requires_grad_(True)

# %%
L =torch.normal(0,torch.ones(L_true.shape[0],L_true.shape[1])).clone().detach().requires_grad_(True)
L_orig = L.clone().detach()
#L =L_true.clone().detach().requires_grad_(True)
scaling1 = torch.rand(1).clone().detach().requires_grad_(True)
lengthscale1 = torch.rand(X_train.shape[1]).clone().detach().requires_grad_(True)
lengthscale_in1=torch.tensor([lengthscale[0],4])

scaling2 = torch.rand(1).clone().detach().requires_grad_(True)
lengthscale2 = torch.rand(X_train.shape[1]).clone().detach().requires_grad_(True)
lengthscale_in2=torch.tensor([lengthscale[0],4])


scaling_true1 = emulator.models[0].covar_module.outputscale.detach().clone().requires_grad_(True)#torch.rand(1).clone().detach().requires_grad_(True)
lengthscale_true1 = torch.rand(X_train.shape[1]).clone().detach().requires_grad_(True)

scaling_true2 = emulator.models[1].covar_module.outputscale.detach().clone().requires_grad_(True)#torch.rand(1).clone().detach().requires_grad_(True)
lengthscale_true2 = emulator.models[1].covar_module.base_kernel.lengthscale.detach().clone().requires_grad_(True) #torch.rand(X_train.shape[1]+L_true.shape[1]).clone().detach().requires_grad_(True)

#lengthscale=lengthscale_true.clone().detach().requires_grad_(True)
#scaling=scaling_true.clone().detach().requires_grad_(True)

sigma2 = torch.tensor([0.001]).clone().detach().requires_grad_(True)
mean = torch.rand(1).clone().detach().requires_grad_(True)
mean=0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 6
#       4 scaling1 = torch.rand(1).clone().detach().requires_grad_(True)
#       5 lengthscale1 = torch.rand(X_train.shape[1]).clone().detach().requires_grad_(True)
# ----> 6 lengthscale_in1=torch.tensor([lengthscale[0],4])
#       8 scaling2 = torch.rand(1).clone().detach().requires_grad_(True)
#       9 lengthscale2 = torch.rand(X_train.shape[1]).clone().detach().requires_grad_(True)
#
# NameError: name 'lengthscale' is not defined

# %%
XL_test = torch.cat((X_test,torch.repeat_interleave(L_true,p,dim=0)),axis=1)
XL_train = torch.cat((X_train,torch.repeat_interleave(L,p,dim=0)),axis=1)

XL_true_test = torch.cat((X_test,torch.repeat_interleave(L_true,p,dim=0)),axis=1)
XL_true_train = torch.cat((X_train,torch.repeat_interleave(L_true,p,dim=0)),axis=1)

# %%
for i in range(L.shape[0]):
    m_p,K_p = posterior_theta(Y,XL_test[i*p:(i+1)*p],XL_train,scaling,lengthscale,sigma2,mean)
    R2=1-((m_p*Y_std+Y_mean-(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean))**2).mean(axis=0)/(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean).std(axis=0)**2
    print(R2,((m_p*Y_std+Y_mean-(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean))**2).mean(axis=0),(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean).std(axis=0)**2)

# %%
for i in range(L.shape[0]):
    m_p,K_p = posterior_theta(Y[:,0],XL_true_test[i*p:(i+1)*p],XL_true_train,scaling_true1,lengthscale_true1,sigma2,mean)
    R2=1-((m_p*Y_std+Y_mean-(Y_test[i*p:(i+1)*p,0]*Y_std+Y_mean))**2).mean(axis=0)/(Y_test[i*p:(i+1)*p,0]*Y_std+Y_mean).std(axis=0)**2
    print(R2,((m_p*Y_std+Y_mean-(Y_test[i*p:(i+1)*p,0]*Y_std+Y_mean))**2).mean(axis=0),(Y_test[i*p:(i+1)*p,0]*Y_std+Y_mean).std(axis=0)**2)

# %%
m_p,K_p = posterior_theta(Y,XL_test,XL_train,scaling,lengthscale,sigma2,mean)
R2=1-((m_p*Y_std+Y_mean-(Y_test*Y_std+Y_mean))**2).mean(axis=0)/(Y_test*Y_std+Y_mean).std(axis=0)**2
print(R2,((m_p*Y_std+Y_mean-(Y_test*Y_std+Y_mean))**2).mean(axis=0),(Y_test*Y_std+Y_mean).std(axis=0)**2)

# %%
m_p,K_p = posterior_theta(Y,XL_true_test,XL_true_train,scaling_true,lengthscale_true,sigma2,mean)
R2=1-((m_p*Y_std+Y_mean-(Y_test*Y_std+Y_mean))**2).mean(axis=0)/(Y_test*Y_std+Y_mean).std(axis=0)**2
print(R2,((m_p*Y_std+Y_mean-(Y_test*Y_std+Y_mean))**2).mean(axis=0),(Y_test*Y_std+Y_mean).std(axis=0)**2)

# %%
cost(Y,XL_train,scaling1,lengthscale1,scaling2,lengthscale2,sigma2,L_dim=1)

# %%
gd = torch.optim.SGD([scaling_true1,lengthscale_true], lr=1e-5)
history_gd = []

for i in range(100000):
    gd.zero_grad()
    objective = cost(Y,XL_true_train,scaling_true,lengthscale_true,sigma2,L_dim=1)
    objective.backward()
    gd.step()
    history_gd.append(objective.item())
    if i%100 ==0:
        print(objective)
    if (i>1) and (np.abs(history_gd[-1] - history_gd[-2]) < .00000000000001):
        print("Convergence achieved in ", i+1, " iterations") 
        print("-LogL Value: ", objective.item())
        break

# %% [markdown]
# ## lengthscale=4

# %%
history_gd = []
scales=[]
lengths=[]
Ls=[]

# %%
L =torch.normal(0,torch.ones(L_true.shape[0],L_true.shape[1])).clone().detach().requires_grad_(True)
scaling1 = (2*torch.rand(1)).clone().detach().requires_grad_(True)
lengthscale1 = (2*torch.rand(X_train.shape[1])).clone().detach().requires_grad_(True)
lengthscale_in1=torch.cat([lengthscale,torch.tensor([4])])

scaling2 = (2*torch.rand(1)).clone().detach().requires_grad_(True)
lengthscale2 = (2*torch.rand(X_train.shape[1])).clone().detach().requires_grad_(True)
lengthscale_in2=torch.cat([lengthscale,torch.tensor([4])])

# %%
gd = torch.optim.Adam([L,scaling1,lengthscale1,scaling2,lengthscale2], lr=1e-5)
for i in range(1000000):
    lengthscale_in1=torch.cat([lengthscale1,torch.tensor([4,4])])
    lengthscale_in2=torch.cat([lengthscale2,torch.tensor([4,4])])
    gd.zero_grad()
    objective = cost(Y,XL_train,scaling1,lengthscale_in1,scaling2,lengthscale_in2,sigma2,L_dim=1)
    objective.backward()
    gd.step()
    history_gd.append(objective.item())
    scales.append(scaling.clone().detach())
    lengths.append(lengthscale.clone().detach())
    Ls.append(L.clone().detach())
    XL_train = torch.cat((X_train,torch.repeat_interleave(L,p,dim=0)),axis=1)
    
    if i%1000 ==0:
        XL_test = torch.cat((X_test,torch.repeat_interleave(L,p,dim=0)),axis=1)
        m_p,K_p = posterior_theta(Y,XL_test,XL_train,scaling1,lengthscale_in1,sigma2,mean)
        R2=1-((m_p*Y_std+Y_mean-(Y_test*Y_std+Y_mean))**2).mean(axis=0)/(Y_test*Y_std+Y_mean).std(axis=0)**2
        print(objective,R2,scaling)
        
    #if (i>1) and (np.abs(history_gd[-1] - history_gd[-2]) < .000000000000000000000001):
        #print("Convergence achieved in ", i+1, " iterations") 
        #print("-LogL Value: ", objective.item())
        #break

# %%
plt.plot(history_gd)

# %%
torch.cat(Ls,axis=0).shape

# %%
plt.plot(torch.cat(Ls,axis=0).detach().numpy(),'o')

# %%
torch.cat(lengths).shape

# %%
plt.plot(torch.cat(lengths).detach().numpy(),'o')

# %%
m_p2,K_p = posterior_theta(Y,XXLL,XL_train,scaling,lengthscale,sigma2,mean)
plt.imshow(m_p2.reshape(100,100).detach().numpy(),origin='lower',extent=[lmin,lmax,xmin,xmax])
plt.plot(XL_train[0:10,1].detach().numpy(),XL_train[0:10,0].detach().numpy(),'o',color='r')
#plt.plot(XL_test[:,1].detach().numpy(),XL_test[:,0].detach().numpy(),'o',color='b')
plt.colorbar()

# %%
m_p,K_p = posterior_theta(Y,XXLL,XL_true_train,scaling_true,lengthscale_true,sigma2,mean)
plt.imshow(m_p.reshape(100,100).detach().numpy(),origin='lower',extent=[lmin,lmax,xmin,xmax])
plt.plot(XL_true_train[0:10,1].detach().numpy(),XL_true_train[0:10,0].detach().numpy(),'o',color='r')
#plt.plot(XL_test[:,1].detach().numpy(),XL_test[:,0].detach().numpy(),'o',color='b')
plt.colorbar()

# %% [markdown]
# ## lengthscale=1

# %%
history_gd = []
scales=[]
lengths=[]
Ls=[]

# %%
L =torch.normal(0,torch.ones(L_true.shape[0],L_true.shape[1])).clone().detach().requires_grad_(True)
scaling = (2*torch.rand(1)).clone().detach().requires_grad_(True)
lengthscale = (2*torch.rand(X_train.shape[1])).clone().detach().requires_grad_(True)
lengthscale_in=torch.cat([lengthscale,torch.tensor([4])])

# %%
gd = torch.optim.Adam([L,scaling,lengthscale], lr=1e-5)
for i in range(1000000):
    lengthscale_in=torch.cat([lengthscale,torch.tensor([1])])
    gd.zero_grad()
    objective = cost(Y,XL_train,scaling,lengthscale_in,sigma2,L_dim=1)
    objective.backward()
    gd.step()
    history_gd.append(objective.item())
    scales.append(scaling.clone().detach())
    lengths.append(lengthscale.clone().detach())
    Ls.append(L.clone().detach())
    XL_train = torch.cat((X_train,torch.repeat_interleave(L,p,dim=0)),axis=1)
    
    if i%1000 ==0:
        XL_test = torch.cat((X_test,torch.repeat_interleave(L,p,dim=0)),axis=1)
        m_p,K_p = posterior_theta(Y,XL_test,XL_train,scaling,lengthscale_in,sigma2,mean)
        R2=1-((m_p*Y_std+Y_mean-(Y_test*Y_std+Y_mean))**2).mean(axis=0)/(Y_test*Y_std+Y_mean).std(axis=0)**2
        print(objective,R2,scaling)
        
    #if (i>1) and (np.abs(history_gd[-1] - history_gd[-2]) < .000000000000000000000001):
        #print("Convergence achieved in ", i+1, " iterations") 
        #print("-LogL Value: ", objective.item())
        #break

# %%
plt.plot(history_gd)

# %%
torch.cat(Ls,axis=1)

# %%
plt.plot(torch.cat(Ls,axis=1).T.detach().numpy())

# %%
torch.cat(lengths).shape

# %%
plt.plot(torch.cat(lengths).detach().numpy(),'o')

# %%
m_p2,K_p = posterior_theta(Y,XXLL,XL_train,scaling,lengthscale,sigma2,mean)
plt.imshow(m_p2.reshape(100,100).detach().numpy(),origin='lower',extent=[lmin,lmax,xmin,xmax])
plt.plot(XL_train[30:40,1].detach().numpy(),XL_train[30:40,0].detach().numpy(),'o',color='r')
#plt.plot(XL_test[:,1].detach().numpy(),XL_test[:,0].detach().numpy(),'o',color='b')
plt.colorbar()

# %%
m_p,K_p = posterior_theta(Y,XXLL,XL_true_train,scaling_true,lengthscale_true,sigma2,mean)
plt.imshow(m_p.reshape(100,100).detach().numpy(),origin='lower',extent=[lmin,lmax,xmin,xmax])
plt.plot(XL_true_train[30:40,1].detach().numpy(),XL_true_train[30:40,0].detach().numpy(),'o',color='r')
#plt.plot(XL_test[:,1].detach().numpy(),XL_test[:,0].detach().numpy(),'o',color='b')
plt.colorbar()

# %% [markdown]
# ## Can we get to the true values?

# %%
history_gd = []
scales=[]
lengths=[]
Ls=[]

# %%
L =torch.normal(0,torch.ones(L_true.shape[0],L_true.shape[1])).clone().detach().requires_grad_(True)
scaling = (torch.rand(1)).clone().detach().requires_grad_(True)
lengthscale = torch.rand(X_train.shape[1]+L_true.shape[1]).clone().detach().requires_grad_(True)

# %%
gd = torch.optim.Adam([scaling,lengthscale], lr=1e-5)
for i in range(500000):
    gd.zero_grad()
    objective = cost(Y,XL_true_train,scaling,lengthscale,sigma2,L_dim=1)
    objective.backward()
    gd.step()
    history_gd.append(objective.item())
    scales.append(scaling.clone().detach())
    lengths.append(lengthscale.clone().detach())
    Ls.append(L.clone().detach())
    
    if i%1000 ==0:
        m_p,K_p = posterior_theta(Y,XL_true_test,XL_true_train,scaling,lengthscale,sigma2,mean)
        R2=1-((m_p*Y_std+Y_mean-(Y_test*Y_std+Y_mean))**2).mean(axis=0)/(Y_test*Y_std+Y_mean).std(axis=0)**2
        print(objective,R2,scaling)
        
    #if (i>1) and (np.abs(history_gd[-1] - history_gd[-2]) < .000000000000000000000001):
        #print("Convergence achieved in ", i+1, " iterations") 
        #print("-LogL Value: ", objective.item())
        #break

# %%
plt.plot(history_gd)

# %%
torch.cat(Ls,axis=1)

# %%
plt.plot(torch.cat(Ls,axis=1).T.detach().numpy())

# %%
torch.cat(lengths).shape

# %%
plt.plot(torch.cat(lengths).detach().numpy(),'o')

# %%
m_p2,K_p = posterior_theta(Y,XXLL,XL_true_train,scaling,lengthscale,sigma2,mean)
plt.imshow(m_p2.reshape(100,100).detach().numpy(),origin='lower',extent=[lmin,lmax,xmin,xmax])
plt.plot(XL_true_train[30:40,1].detach().numpy(),XL_true_train[30:40,0].detach().numpy(),'o',color='r')
#plt.plot(XL_test[:,1].detach().numpy(),XL_test[:,0].detach().numpy(),'o',color='b')
plt.colorbar()

# %%
m_p,K_p = posterior_theta(Y,XXLL,XL_true_train,scaling_true,lengthscale_true,sigma2,mean)
plt.imshow(m_p.reshape(100,100).detach().numpy(),origin='lower',extent=[lmin,lmax,xmin,xmax])
plt.plot(XL_true_train[30:40,1].detach().numpy(),XL_true_train[30:40,0].detach().numpy(),'o',color='r')
#plt.plot(XL_test[:,1].detach().numpy(),XL_test[:,0].detach().numpy(),'o',color='b')
plt.colorbar()

# %%
plt.plot(torch.tensor(scales).detach().numpy())

# %%
scaling_true

# %%
scaling

# %%
Y_test.std()

# %%
print(R2,((m_p*Y_std+Y_mean-(Y_test*Y_std+Y_mean))**2).mean(axis=0),(Y_test*Y_std+Y_mean).std(axis=0)**2)

# %%
m_p,K_p = posterior_theta(Y,XL_true_test,XL_true_train,scaling_true,lengthscale_true,sigma2,mean)
R2=1-((m_p*Y_std+Y_mean-(Y_test*Y_std+Y_mean))**2).mean(axis=0)/(Y_test*Y_std+Y_mean).std(axis=0)**2
print(R2,((m_p*Y_std+Y_mean-(Y_test*Y_std+Y_mean))**2).mean(axis=0),(Y_test*Y_std+Y_mean).std(axis=0)**2)

# %%
m_p,K_p = posterior_theta(Y,XL_train,XL_train,scaling,lengthscale,sigma2,mean)
R2=1-((m_p*Y_std+Y_mean-(Y*Y_std+Y_mean))**2).mean(axis=0)/(Y*Y_std+Y_mean).std(axis=0)**2
print(R2,((m_p*Y_std+Y_mean-(Y*Y_std+Y_mean))**2).mean(axis=0),(Y*Y_std+Y_mean).std(axis=0)**2)

# %%
m_p,K_p = posterior_theta(Y,XL_true_train,XL_true_train,scaling_true,lengthscale_true,sigma2,mean)
R2=1-((m_p*Y_std+Y_mean-(Y*Y_std+Y_mean))**2).mean(axis=0)/(Y*Y_std+Y_mean).std(axis=0)**2
print(R2,((m_p*Y_std+Y_mean-(Y*Y_std+Y_mean))**2).mean(axis=0),(Y*Y_std+Y_mean).std(axis=0)**2)

# %%
m_p,K_p = posterior_theta(Y,XXLL,XL_true_train,scaling,lengthscale,sigma2,mean)

# %%
XXLL.min(axis=0)

# %%
m_p,K_p = posterior_theta(Y,XXLL,XL_true_train,scaling_true,lengthscale_true,sigma2,mean)
plt.imshow(m_p.reshape(100,100).detach().numpy(),origin='lower',extent=[lmin,lmax,xmin,xmax])
plt.plot(XL_true_train[:,1].detach().numpy(),XL_true_train[:,0].detach().numpy(),'o',color='r')
#plt.plot(XL_test[:,0].detach().numpy(),XL_test[:,1].detach().numpy(),'o',color='b')
plt.colorbar()

# %%
XL_train

# %%
m_p2,K_p = posterior_theta(Y,XXLL,XL_train,scaling,lengthscale,sigma2,mean)
plt.imshow(m_p2.reshape(100,100).detach().numpy(),origin='lower',extent=[lmin,lmax,xmin,xmax])
plt.plot(XL_train[:,1].detach().numpy(),XL_test[:,0].detach().numpy(),'o',color='r')
#plt.plot(XL_test[:,1].detach().numpy(),XL_test[:,0].detach().numpy(),'o',color='b')
plt.colorbar()

# %%
lengthscale

# %%
L

# %%
scaling

# %%
lengthscale_true

# %%
m_p,K_p = posterior_theta(Y,XXLL,XL_true_train,scaling_true,lengthscale_true,sigma2,mean)
plt.imshow((m_p.reshape(100,100).detach().numpy()-m_p2.reshape(100,100).detach().numpy())**2,origin='lower',extent=[lmin,lmax,xmin,xmax])
#plt.plot(XL_train[:,0].detach().numpy(),XL_train[:,1].detach().numpy(),'o',color='r')
#plt.plot(XL_test[:,0].detach().numpy(),XL_test[:,1].detach().numpy(),'o',color='b')
plt.colorbar()

# %%
plt.imshow(emulator.predict(XXLL).reshape(100,100).detach().numpy(),origin='lower',extent=[lmin,lmax,xmin,xmax])
plt.colorbar()

# %%
m_p,K_p = posterior_theta(Y,XXLL,XL_true_train,scaling_true,lengthscale_true,sigma2,mean)
plt.imshow(m_p.reshape(100,100).detach().numpy()-emulator.predict(XXLL).reshape(100,100).detach().numpy(),origin='lower',extent=[lmin,lmax,xmin,xmax])
plt.colorbar()

# %%
L_true

# %%
L

# %%
for i in range(L.shape[0]):
    m_p,K_p = posterior_theta(Y,XL_test[i*p:(i+1)*p],XL_train,scaling,lengthscale,sigma2,mean)
    R2=1-((m_p*Y_std+Y_mean-(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean))**2).mean(axis=0)/(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean).std(axis=0)**2
    print(R2,((m_p*Y_std+Y_mean-(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean))**2).mean(axis=0),(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean).std(axis=0)**2)

# %%
for i in range(L.shape[0]):
    m_p,K_p = posterior_theta(Y,XL_test[i*p:(i+1)*p],XL_train,scaling,lengthscale,sigma2,mean)
    R2=1-((m_p-(Y_test[i*p:(i+1)*p,:]))**2).mean(axis=0)/(Y_test[i*p:(i+1)*p,:]).std(axis=0)**2
    print(R2,((m_p*Y_std+Y_mean-(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean))**2).mean(axis=0),(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean).std(axis=0)**2)

# %% [markdown]
# ### Test 2

# %%
N = 10 #number of systems
p = 20 #observations per system
alpha=10
beta=-7
zeta=5

# %%
L_true=torch.FloatTensor(N, 2).uniform_(-1, 1)

# %%
L_true[0]

# %%
multivariate_ll(L_true,0,torch.eye(N),K_inv=None)

# %%
import scipy
np.sum(scipy.stats.multivariate_normal.logpdf(L_true.T.detach().numpy(),cov=np.eye(N)))

# %%
X_train=torch.torch.FloatTensor(N*p, 2).uniform_(-1, 1)
X_test=torch.torch.FloatTensor(N*p, 2).uniform_(-1, 1)

# %%
L_true[[0]][0]

# %%
def true_func(X,L,alpha,beta,zeta):
    tf = alpha*X[:,[0]]*X[:,[ 0]]*L[:,0]+beta*L[:,1]*X[:,[ 1]]+zeta+torch.normal(0,0.01*torch.ones(X.shape[0],1))
    return tf

# %%
y=[]
y_test = []
for i in range(N):
    y.append(true_func(X_train[i*p:(i+1)*p],L_true[[i]],alpha,beta,zeta))
    y_test.append(true_func(X_test[i*p:(i+1)*p],L_true[[i]],alpha,beta,zeta))

# %%
Y=torch.cat(y)
Y_test=torch.cat(y_test)

# %%
Y.shape

# %%
Y_mean = Y.mean()
Y_std = Y.std()

X_mean = X_train.mean()
X_std =X_train.std()

X_train = (X_train-X_mean)/X_std
X_test = (X_test-X_mean)/X_std

# %%
X_train[i*p:(i+1)*p,0].shape

# %%
emulators=[]
for i in range(N):
    emulators.append(GPE.ensemble(X_train[i*p:(i+1)*p,:],Y[i*p:(i+1)*p],mean_func='zero'))

# %%
for i in range(N):
    print(emulators[i].R2(X_test[i*p:(i+1)*p,:],(Y_test[i*p:(i+1)*p])))

# %%
Y=(Y-Y_mean)/Y_std
Y_test=(Y_test-Y_mean)/Y_std

# %%
def cost(y,X,L,scaling,lengthscale,sigma2,p,mean=0):
    

    K=rbf(X,L,X,L,scaling,lengthscale,p,p)+sigma2*torch.eye(X.shape[0])
    
    #K_inv=torch.kron(torch.linalg.inv(K_x),torch.linalg.inv(K_L))
    #K_inv=torch.kron(torch.linalg.inv(K_L),torch.linalg.inv(K_x))
    #print(torch.linalg.det(K))
    c = multivariate_ll(y,mean,K) + multivariate_ll(L,0,torch.eye(L.shape[0])) # multivariate_ll(torch.repeat_interleave(L,x.shape[0])[:,None],0,torch.eye(inp.shape[0]))
    return -c

# %%
L = torch.rand(L_true.shape[0],L_true.shape[1]).clone().detach().requires_grad_(True)

# %%
L =torch.normal(0,torch.ones(L_true.shape[0],L_true.shape[1])).clone().detach().requires_grad_(True)
#L =L_true.clone().detach().requires_grad_(True)
scaling = torch.rand(1).clone().detach().requires_grad_(True)
lengthscale = torch.rand(X_train.shape[1]+L_true.shape[1]).clone().detach().requires_grad_(True)
sigma2 = torch.tensor([0.000001]).clone().detach().requires_grad_(True)
mean = torch.rand(1).clone().detach().requires_grad_(True)
mean=0

# %%
for i in range(L.shape[0]):
    m_p,K_p = posterior_theta(Y[i*p:(i+1)*p],X_test[i*p:(i+1)*p],L[[i]],p,X_train[i*p:(i+1)*p],L[[i]],p,scaling,lengthscale,sigma2,mean)
    R2=1-((m_p*Y_std+Y_mean-(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean))**2).mean(axis=0)/(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean).std(axis=0)**2
    print(R2)

# %%
cost(Y,X_train,L,scaling,lengthscale,sigma2,p)

# %%
#plt.imshow(rbf(X,L,X,L,scaling,lengthscale,p,p).detach().numpy())

# %%
plt.imshow(rbf(X_train,L,X_train,L,scaling,lengthscale,p,p).detach().numpy())

# %%
for i in range(N):
    plt.plot(X_train[i*p:(i+1)*p,0],Y[i*p:(i+1)*p],'o')

# %%
cost(Y,X_train,L_true,scaling,lengthscale,sigma2,p)

# %%
gd = torch.optim.Adam([L,scaling,lengthscale], lr=1e-5)
history_gd = []

for i in range(100000):
    gd.zero_grad()
    objective = cost(Y,X_train,L,scaling,lengthscale,sigma2,p)
    objective.backward()
    gd.step()
    history_gd.append(objective.item())
    if i%1000 ==0:
        print(objective)
    if (i>1) and (np.abs(history_gd[-1] - history_gd[-2]) < .0000000000000000000001):
        print("Convergence achieved in ", i+1, " iterations") 
        print("-LogL Value: ", objective.item())
        break

# %%
L_true

# %%
L

# %%
lengthscale

# %%
cost(Y,X_train,L_true,scaling,lengthscale,sigma2,p,mean)

# %%
cost(Y,X_train,L,scaling,lengthscale,sigma2,p,mean)

# %%
mean

# %%
m_p,K_p = posterior_theta(Y,X_test,L,p,X_train,L,p,scaling,lengthscale,sigma2,mean)
R2=1-((m_p*Y_std+Y_mean-(Y_test*Y_std+Y_mean))**2).mean(axis=0)/(Y_test*Y_std+Y_mean).std(axis=0)**2
print(R2)

# %%
X_test[i*p:(i+1)*p:,].shape

# %%
for i in range(L.shape[0]):
    m_p,K_p = posterior_theta(Y,X_test[i*p:(i+1)*p],L[[i]],p,X_train,L,p,scaling,lengthscale,sigma2,mean)
    R2=1-((m_p*Y_std+Y_mean-(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean))**2).mean(axis=0)/(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean).std(axis=0)**2
    print(R2)

# %%
for i in range(L.shape[0]):
    m_p,K_p = posterior_theta(Y,X_test[i*p:(i+1)*p],L_true[[i]],p,X_train,L_true,p,scaling,lengthscale,sigma2,mean)
    R2=1-((m_p*Y_std+Y_mean-(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean))**2).mean(axis=0)/(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean).std(axis=0)**2
    print(R2)

# %%
for i in range(N):
    print(emulators[i].R2(X_test[i*p:(i+1)*p,:],(Y_test[i*p:(i+1)*p])*Y_std+Y_mean))

# %%
cost(Y,X_train,L,scaling,lengthscale,sigma2,p)

# %%
cost(Y,X_train,L_true,scaling,lengthscale,sigma2,p)

# %%
#plt.imshow(rbf(X,L,X,L,scaling,lengthscale,p,p).detach().numpy())

# %%
plt.imshow(rbf(X_train,L,X_train,L,scaling,lengthscale,p,p).detach().numpy())

# %%
for i in range(N):
    plt.plot(X_train[i*p:(i+1)*p,0],Y[i*p:(i+1)*p],'o')

# %%
cost(Y,X_train,L_true,scaling,lengthscale,sigma2,p)

# %%
gd = torch.optim.Adam([L,scaling,lengthscale], lr=1e-5)
history_gd = []

for i in range(100000):
    gd.zero_grad()
    objective = cost(Y,X_train,L,scaling,lengthscale,sigma2,p)
    objective.backward()
    gd.step()
    history_gd.append(objective.item())
    if i%1000 ==0:
        print(objective)
    if (i>1) and (np.abs(history_gd[-1] - history_gd[-2]) < .00000001):
        print("Convergence achieved in ", i+1, " iterations") 
        print("-LogL Value: ", objective.item())
        break

# %%
L_true

# %%
L

# %%
m_p,K_p = posterior_theta(Y,X_test,L,p,X_train,L,p,scaling,lengthscale,sigma2,mean)
R2=1-((m_p*Y_std+Y_mean-(Y_test*Y_std+Y_mean))**2).mean(axis=0)/(Y_test*Y_std+Y_mean).std(axis=0)**2
print(R2)

# %%
X_test[i*p:(i+1)*p:,].shape

# %%
for i in range(L.shape[0]):
    m_p,K_p = posterior_theta(Y[i*p:(i+1)*p],X_test[i*p:(i+1)*p],L[[i]],p,X_train[i*p:(i+1)*p],L[[i]],p,scaling,lengthscale,sigma2,mean)
    R2=1-((m_p*Y_std+Y_mean-(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean))**2).mean(axis=0)/(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean).std(axis=0)**2
    print(m_p[0],R2)

# %%
for i in range(L.shape[0]):
    m_p,K_p = posterior_theta(Y[i*p:(i+1)*p],X_test[i*p:(i+1)*p],L_true[[i]],p,X_train[i*p:(i+1)*p],L_true[[i]],p,scaling,lengthscale,sigma2,mean)
    R2=1-((m_p*Y_std+Y_mean-(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean))**2).mean(axis=0)/(Y_test[i*p:(i+1)*p,:]*Y_std+Y_mean).std(axis=0)**2
    print(m_p[0],R2)

# %%
for i in range(N):
    print(emulators[i].R2(X_test[i*p:(i+1)*p,:],(Y_test[i*p:(i+1)*p])*Y_std+Y_mean))

# %%
p_new = 20
X_new=torch.torch.FloatTensor(p_new, 1).uniform_(-1, 1)
L_new =torch.normal(0,torch.ones(1,L_true.shape[1]))
#L_new=L_true[[1]]
Y_new=true_func(X_new,L_new,alpha,beta,zeta)

Y_new_mean = Y_new.mean()
Y_new_std = Y_new.std()

Y_new = (Y_new-Y_mean)/Y_std

# %%
plt.plot(X_new[:,0].detach().numpy(),Y_new.detach().numpy(),'o')

# %%
def cf_cost(Y_new,X_new,L_new,Y_train,X_train,L_train,scaling,lengthscale,sigma2,p_train,p_new,mean):
    
    
    mean_p,K_p = posterior_theta(Y_train,X_new,L_new,p_new,X_train,L_train,p_train,scaling,lengthscale,sigma2,mean)
    
    #K_inv=torch.kron(torch.linalg.inv(K_x),torch.linalg.inv(K_L))
    #K_inv=torch.kron(torch.linalg.inv(K_L),torch.linalg.inv(K_x))
    #print(torch.linalg.det(K))
    c = multivariate_ll(Y_new,mean_p,K_p)  + multivariate_ll(L_new,0,torch.eye(L_new.shape[0])) # multivariate_ll(torch.repeat_interleave(L,x.shape[0])[:,None],0,torch.eye(inp.shape[0]))
    #print(multivariate_ll(Y_new,mean_p,K_p))
    #print(multivariate_ll(L_new,0,torch.eye(L_new.shape[0])))
    return -c

# %%
cf_cost(Y_new,X_new,L_new,Y,X_train,L,scaling,lengthscale,sigma2,p,p_new,mean)

# %%
mean_p,K_p = posterior_theta(Y,X_new,L_cf,p_new,X_train,L,p,scaling,lengthscale,sigma2,mean)

# %%
plt.imshow(K_p.detach().numpy())

# %%
mean_p

# %%
Y_new

# %%
L_cf =torch.normal(0,torch.ones(1,L_true.shape[1])).clone().detach().requires_grad_(True)
#L_cf = (L[[1]]).clone().detach().requires_grad_(True)

# %%
cf_cost(Y_new,X_new,L_cf,Y,X_train,L,scaling,lengthscale,sigma2,p,p_new,mean)

# %%
cf = torch.optim.Adam([L_cf], lr=1e-5)
history_cf = []

for i in range(100000):
    cf.zero_grad()
    objective = cf_cost(Y_new,X_new,L_cf,Y,X_train,L,scaling,lengthscale,sigma2,p,p_new,mean)
    objective.backward()
    cf.step()
    history_cf.append(objective.item())
    if i%1000 ==0:
        m_new, K_new = posterior_theta(Y,X_new,L_cf,p_new,X_train,L,p,scaling,lengthscale,sigma2,mean)
        print(1-(((m_new-Y_new)**2).mean()/Y_new.std()**2),objective)

    if (i>1) and (np.abs(history_cf[-1] - history_cf[-2]) < .00000000001):
        print("Convergence achieved in ", i+1, " iterations")
        print("-LogL Value: ", objective.item())
        break

# %%
L_cf

# %%
L[[1]]

# %%
m_new, K_new = posterior_theta(Y,X_new,L_cf,p_new,X_train,L,p,scaling,lengthscale,sigma2,mean)

# %%
K_new.detach().numpy()

# %%
multivariate_ll(Y_new,m_new, K_new) + multivariate_ll(L_cf,0,torch.eye(L_new.shape[0]))

# %%
multivariate_ll(Y_new,m_new, K_new)

# %%
multivariate_ll(L_cf,0,torch.eye(L_new.shape[0]))

# %%
1-(((m_new-Y_new)**2).mean())/Y_new.std()

# %%
m_new

# %%
Y_new

# %%
mean
